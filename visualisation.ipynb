# %% [markdown]
# # BCI IV 2a Epochs

# %%
import os, mne
import matplotlib.pyplot as plt

# %%
directory = "./preprocessed_data/BCI_IV_2a"

s1_epochs = os.path.join(directory, "S01", "PA01T-epo.fif")
epochs = mne.read_epochs(s1_epochs)
epochs
# Out:
# Reading c:\projects\eeg_transformer\preprocessed_data\BCI_IV_2a\S01\PA01T-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    1000.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 144 matching events found
# No baseline correction applied
# 0 projection items activated
# <EpochsFIF | 144 events (all good), 1 – 4 s (baseline off), ~18.2 MiB, data loaded,
#  'left_hand': 72
#  'right_hand': 72>

# %% [markdown]
# # Physionet Epochs

# %%
directory = "./preprocessed_data/Physionet"

filename_epochs_3s = os.path.join(directory, "S054", "PA054-3s-epo.fif")
filename_epochs_6s = os.path.join(directory, "S054", "PA054-6s-epo.fif")
epochs_3s = mne.read_epochs(filename_epochs_3s)
epochs_6s = mne.read_epochs(filename_epochs_6s)
epochs_3s
# Out:
# Reading c:\projects\eeg_transformer\preprocessed_data\Physionet\S054\PA054-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading c:\projects\eeg_transformer\preprocessed_data\Physionet\S054\PA054-6s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    1000.00 ...    7000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# <EpochsFIF | 42 events (all good), 2 – 5 s (baseline off), ~9.9 MiB, data loaded,
#  'left_hand': 21
#  'right_hand': 21>

# %%
epochs_6s
# Out:
# <EpochsFIF | 42 events (all good), 1 – 7 s (baseline off), ~19.8 MiB, data loaded,
#  'left_hand': 21
#  'right_hand': 21>

# %%
evoked_right = epochs_3s['right_hand'].average()

evoked_right.plot()
plt.show()

# %%
evoked_right = epochs_6s['right_hand'].average()

evoked_right.plot()
plt.show()
