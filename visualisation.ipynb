# %% [markdown]
# # BCI IV 2a Epochs

# %%
import os, mne
import matplotlib.pyplot as plt

# %%
directory = "./preprocessed_data/BCI_IV_2a"

s1_epochs = os.path.join(directory, "S01", "PA01T-epo.fif")
epochs = mne.read_epochs(s1_epochs)
epochs
# Out:
# Reading c:\projects\eeg_transformer\preprocessed_data\BCI_IV_2a\S01\PA01T-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    1000.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 144 matching events found
# No baseline correction applied
# 0 projection items activated
# <EpochsFIF | 144 events (all good), 1 – 4 s (baseline off), ~18.2 MiB, data loaded,
#  'left_hand': 72
#  'right_hand': 72>

# %% [markdown]
# ## Evoked left hand

# %%
evoked_left = epochs['left_hand'].average()

evoked_left.plot()
plt.show()

# %% [markdown]
# ## Evoked right hand

# %%
evoked_right = epochs['right_hand'].average()

evoked_right.plot()
plt.show()

# %% [markdown]
# ## Compare evoked

# %%
mne.viz.plot_compare_evokeds({"left": evoked_left, "right": evoked_right})
# Out:
# combining channels using GFP (eeg channels)
# combining channels using GFP (eeg channels)
# [<Figure size 800x600 with 1 Axes>]

# %% [markdown]
# # Physionet Epochs

# %%
directory = "./preprocessed_data/Physionet"

s1_epochs = os.path.join(directory, "S001", "PA001R04-epo.fif")
epochs = mne.read_epochs(s1_epochs)
epochs
# Out:
# Reading c:\projects\eeg_transformer\preprocessed_data\Physionet\S001\PA001R04-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    1000.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# <EpochsFIF | 30 events (all good), 1 – 4 s (baseline off), ~7.1 MiB, data loaded,
#  'rest': 15
#  'left_hand': 8
#  'right_hand': 7>

# %% [markdown]
# ## Evoked left hand

# %%
evoked_left = epochs['left_hand'].average()

evoked_left.plot()
plt.show()

# %% [markdown]
# ## Evoked right hand

# %%
evoked_right = epochs['right_hand'].average()

evoked_right.plot()
plt.show()

# %% [markdown]
# ## Compare evoked

# %%
mne.viz.plot_compare_evokeds({"left": evoked_left, "right": evoked_right})
# Out:
# combining channels using GFP (eeg channels)
# combining channels using GFP (eeg channels)
# [<Figure size 800x600 with 1 Axes>]
