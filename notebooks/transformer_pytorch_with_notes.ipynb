# %% [markdown]
# # Mount dysk konta google do notebooka

# %%
from google.colab import drive
drive.flush_and_unmount()  # Unmount the drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install mne
# Out:
# Requirement already satisfied: mne in /usr/local/lib/python3.11/dist-packages (1.9.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from mne) (4.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from mne) (3.1.6)
# Requirement already satisfied: lazy-loader>=0.3 in /usr/local/lib/python3.11/dist-packages (from mne) (0.4)
# Requirement already satisfied: matplotlib>=3.6 in /usr/local/lib/python3.11/dist-packages (from mne) (3.10.0)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.11/dist-packages (from mne) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from mne) (24.2)
# Requirement already satisfied: pooch>=1.5 in /usr/local/lib/python3.11/dist-packages (from mne) (1.8.2)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.11/dist-packages (from mne) (1.14.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from mne) (4.67.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6->mne) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6->mne) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6->mne) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6->mne) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6->mne) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6->mne) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6->mne) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.5->mne) (4.3.7)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.5->mne) (2.32.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->mne) (3.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.6->mne) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2025.1.31)

# %% [markdown]
# ---
# # Legenda:
#
# <font color="lightgreen">▬ </font>Teoria<br>
# <font color="lightblue">▬ </font>Cytaty z artykułu<br>
# <font color="pink">▬ </font>Implementacja<br>

# %% [markdown]
# ---
#
# # <font color="lightgreen"> Architektura modeli</font>
#
# (Wszystko w kursywie koloru niebieskiego jest z artykułu.)
#
# <font color="lightblue">*The network consisted of Transformer
#  modules as well as operations of Positional Embedding.
#  We also designed methods that combined the CNN module
#  and the Transformer module. CNN was included because
#  of its good properties for feature representation [5].*</font>
#
#  <font color="lightblue">*In the implementation, we built a total of **five** Transformer-based
#  models in which two models only relied on the Transformer
#  without including the CNN and three models used network
#  architecture of combined CNN and Transformer. After the
#  CNN and the Transformer modules, we included a fully
# connected layer.*
#
# *In this study, we employed **h = 8 parallel attention layers
#  (so-called 8 attention heads)**, and solely embedded the encoder
#  part of Transformer into the EEG classification.*</font>
#
# ---
#
#  <font color="lightblue">*The Transformer module had two submodules. The
#  first submodule included a multi-head attention layer followed
#  by a normalization layer. The second submodule included a
#  position-wise fully connected feed-forward layer followed by
#  a normalization layer. The residual connection was employed
#  around each of the two submodules.*</font>

# %% [markdown]
# <img src="https://builtin.com/sites/www.builtin.com/files/styles/ckeditor_optimize/public/inline-images/Transformer-neural-network-12.png" width="400">

# %% [markdown]
# # <font color='lightgreen'>Terminologia</font>
#
# *   **Gradient** - mierzy zmianę wszystkich wag w odniesieniu do zmiany błędu
# *   **Funkcja aktywacji** - kiedy budujemy sieć nueronową, musimy zdecydować, jaką taka funkcjębędziemy używać.
# Duża ilość ludzi używa Funkcji sigmoidalnej, ale w praktyce częściej używa się ReLU, albo Softplus
#
# *   **ReLU** - Jest ona zdefiniowana jako f(x) = max(0, x), co oznacza, że ​​wyprowadza ona wartość wejściową bezpośrednio, jeśli jest dodatnia, a zero w przeciwnym wypadku. Bez niej, sieć neuronowa byłaby po prostu... jednym wielkim wzorem liniowym.
#
# ```python
#     # feed-forward layer
#     self.ff = nn.Sequential(
#         # This changes the size of each input vector from d_model (e.g. 64) to 512.
#         nn.Linear(d_model, 512),
#         nn.ReLU(), # Without it, the two Linear layers would just collapse into a single linear function (no point).
#         nn.Linear(512, d_model) #wraca do początkowego wymiaru, bo reszta transformera wymaga rozmiaru d_model
#     )
#
#
#
# ```
#
#
# *   **Attention** - The key/value/query concept is analogous to retrieval systems. For example, when you search for videos on Youtube, the search engine will map your query (text in the search bar) against a set of keys (video title, description, etc.) associated with candidate videos in their database, then present you the best matched videos (values).
#
#   ---
#   Spatial Transformer (s-Trans)
#   You treat channels (electrodes) as the sequence.
#   Each vector = EEG signal from a channel across time
#
#   So: each channel attends to other channels
#   → “What can I learn from other electrodes?”
#
#   ---
#   Temporal Transformer (t-Trans)
#   Now, you treat time points as the sequence.
#
#   Each vector = EEG signal from all channels at one time point
#
#   So: each time point attends to other time points → “What’s important in the signal over time?”
#
# *   **Feed forward** - najwcześniejsza i najprostsza forma sieci neuronowej. Dane są podawane do przodu (fed forward) z jednej warsty do następnej. Występuje po wartswie attention. Dostajemy na input znormalizowany output z attention.
#
#   *In the context of transformers, the feed-forward network is a sub-unit within each encoder and decoder layer. It takes the output from the self-attention layer, which captures relationships between different parts of the input sequence, and transforms it further*
#
#   Dodaje kolejną warstwę złożoności, stosując funkcje nieliniowe do tych reprezentacji. Dzięki temu model może uczyć się bardziej skomplikowanych wzorców w danych.
#
#   Może być również postrzegana jako sposób na udoskonalenie cech wyodrębnionych przez warstwę samouwagi. Może podkreślać ważne cechy i tłumić mniej istotne, dzięki czemu końcowy wynik jest bardziej pouczający.
#
#   src = https://medium.com/@punya8147_26846/understanding-feed-forward-networks-in-transformers-77f4c1095c67
#
#
# *  **Conv2d** :<br>
#   **KERNEL** - opisuje filtr, który zamierzamy przekazać (w przypadku obrazów) na obraz wejściowy.
#
#   <br><img src="https://miro.medium.com/v2/resize:fit:828/format:webp/0*A0hPszjXFj1S2FZ6.png" width="500">
#   <br><img src="https://miro.medium.com/v2/resize:fit:786/format:webp/1*LT0l-KXw5FXIkcGVl-KXlQ.gif" width="500">
#
#   W EEG mając
#    ```python
#   X shape: (batch, 1, 64, 481)  # ← means:
#   # batch = 32
#   # 1 input channel (grayscale EEG)
#   # 64 EEG channels (spatial dimension)
#   # 481 time points (temporal dimension)
#    ```
#   Mamy na dobrą sprawę "obrazki" EEG w wymiarze 64 x 481
#
#   Pisząc
#   ```python
#   nn.Conv2d(1, 64, (64, 1))
#   ```
#
#   Oczekujemy 1 kanału na input<br>
#   CNN nauczy się 64 takich filtrów<br>
#   Kernel widzi 64 wiersze x 1 kolumnę, czyli wszystkie kanały naraz

# %% [markdown]
# # <font color="pink"> Moduł Transformera</font>

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


"""
d_model -> wymiar wektorów osadzonych (embeddingów)
ReLU    -> to funkcja aktywacji (tutorial: https://www.youtube.com/watch?v=68BZ5f7P94E)
norm1 i norm2 -> To są warstwy Layer Normalization, normalizują dane na poziomie każdej próbki

"""
class TransformerBlock(nn.Module):
  def __init__(self, d_model, nhead):
    super(TransformerBlock, self).__init__()
    self.attn = nn.MultiheadAttention(d_model, nhead, dropout=0.3)

    # feed-forward layer
    self.ff = nn.Sequential(
        nn.Linear(d_model, 512),
        nn.ReLU(),
        nn.Linear(512, d_model)
    )

    self.norm1 = nn.LayerNorm(d_model)
    self.norm2 = nn.LayerNorm(d_model)

  def forward(self, x):

    # output, _ = attention(query=x, key=x, value=x)
    attn_output, _ = self.attn(x, x, x)

    """
    x + attn_output -> to residual connection, czyli technika projektowania sieci neuronowych,
    która pozwala warstwom pomijać się nawzajem, co pomaga w szkoleniu głębszych sieci.
    Dodajesz oryginalne dane wejściowe (x) do danych wyjściowych uwagi.

    It lets the model say:
    “I’ll keep most of what I had, and only adjust a little.”

    It helps the gradient flow backward during training.
    """
    x = self.norm1(x + attn_output)
    ff_output = self.ff(x)
    x = self.norm2(x + ff_output)
    return x

# %% [markdown]
# # Jak tego używamy
#
# ```
# Input x
#  ↓
# Multi-head attention
#  ↓
# x = x + attention_output        ← residual
# x = LayerNorm(x)                ← normalization
#  ↓
# Feed-forward
#  ↓
# x = x + feedforward_output      ← residual
# x = LayerNorm(x)                ← normalization
#
# ```
# | Line of Code                            | What it Does                       | Why It's Important                                                                 |
# |----------------------------------------|------------------------------------|------------------------------------------------------------------------------------|
# | `attn_output, _ = self.attn(x, x, x)`  | Applies multi-head self-attention | Learns dependencies across time or channels (e.g. between electrodes or moments)  |
# | `x = self.norm1(x + attn_output)`      | Residual + LayerNorm               | Makes training stable and allows deeper models by preserving gradient flow        |
# | `ff_output = self.ff(x)`               | Feed-forward network               | Applies non-linear transformation at each position (enriches representation)      |
# | `x = self.norm2(x + ff_output)`        | Another residual + LayerNorm       | Further stabilization and refined representation                                  |
# | `return x`                             | Returns transformed output         | Feeds the improved signal into the next layer or classifier                       |
#
# <br>
# <br>
#
#
# Używamy trzechy modułów Transformera:<br>
# <font color="lightblue">*We explored the influence of the number of Transformer modules on the classification results. The number of Transformer modules was tested from 1 to 6. When the number of 3 was chosen, the classification achieved the best results. We therefore included three Transformer modules in our models.*</font>
#
# ```python
# # Czyli np
# class SpatialTransformer(nn.Module):
#     def __init__(...):
#         ...
#         self.transformer = nn.Sequential(
#             TransformerBlock(d_model, nhead),
#             TransformerBlock(d_model, nhead),
#             TransformerBlock(d_model, nhead)
#         )
#
#
# ```

# %% [markdown]
# # <font color="pink"> Positional encoding</font>

# %%
class PositionalEncoding(nn.Module):
  # 1000, bo dla 3s mamy 480 próbek, dla 6s 960 (physionet)
  def __init__(self, d_model, max_len=1000):
    super(PositionalEncoding, self).__init__()
    pe = torch.zeros(max_len, d_model)
    position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
    div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-torch.log(torch.tensor(10000.0)) / d_model))
    # For even indices (dimension 2i):
    # PE(pos, 2i) = sin(pos / (10000^(2i / d_model))) ---> (10000^(2i / d_model)) === div_term
    pe[:, 0::2] = torch.sin(position * div_term)
    # For odd indices (dimension 2i+1):
    # PE(pos, 2i+1) = cos(pos / (10000^(2i / d_model)))
    pe[:, 1::2] = torch.cos(position * div_term)

    pe = pe.unsqueeze(0).transpose(0, 1)
    self.register_buffer('pe', pe)

  def forward(self, x):
    return x + self.pe[:x.size(0), :]

# %% [markdown]
# # <font color="pink"> Spatial Transformer</font>

# %%
# Learns dependencies between channel
class SpatialTransformer(nn.Module):
  def __init__(self, input_size, d_model, nhead, num_classes):
    super(SpatialTransformer, self).__init__()
    self.embedding = nn.Linear(input_size, d_model)
    self.pos_encoder = PositionalEncoding(d_model)
    self.transformer = nn.Sequential(
        TransformerBlock(d_model, nhead),
        TransformerBlock(d_model, nhead),
        TransformerBlock(d_model, nhead)
    )
    self.fc = nn.Linear(d_model, num_classes)

  def forward(self, x):
    x = x.permute(1, 0, 2) # (channels, batch, time)
    x = self.embedding(x)
    x = self.pos_encoder(x)
    x = self.transformer(x)
    x = x.mean(dim=0)
    return self.fc(x)

# %% [markdown]
# # <font color="pink"> Temporal Transformer</font>

# %%
# Transformer learns relationships between time points
class TemporalTransformer(nn.Module):
    def __init__(self, input_size, d_model, nhead, num_classes):
        super(TemporalTransformer, self).__init__()
        self.embedding = nn.Linear(input_size, d_model)
        self.pos_encoder = PositionalEncoding(d_model)
        self.transformer = nn.Sequential(
            TransformerBlock(d_model, nhead),
            TransformerBlock(d_model, nhead),
            TransformerBlock(d_model, nhead)
        )
        self.fc = nn.Linear(d_model, num_classes)

    def forward(self, x):  # x shape: (batch, channels, time)
        x = x.permute(2, 0, 1)  # (time, batch, channels)
        x = self.embedding(x)
        x = self.pos_encoder(x)
        x = self.transformer(x)
        x = x.mean(dim=0)
        return self.fc(x)

# %% [markdown]
# ![obraz_2025-04-15_213131017.png](data:image/png;base64,...)

# %% [markdown]
# # <font color="pink"> Spatial CNN Transformer</font>
#
#
#   <font color="lightblue">*In the spatial implementation of the CNN + Transformer
#  model (s-CTrans, Fig. 3c), the CNN module included two
#  convolutional layers and one average pooling layer. In the first
#  convolutional layer, we used 64 kernels with the size of 1 × 16
#  (channel × time points) to extract EEG temporal information,
#  and adopted the SAME padding. The average pooling layer
#  had the pooling size of 1 × 32. The second convolutional
#  layer used 64 kernels with the size of 1 × 15, and adopted
#  the VALID padding*</font>

# %%
# Uses CNN to help extract temporal features per channel, then model channel relations
class SpatialCNNTransformer(nn.Module):
    def __init__(self, input_size, d_model, nhead, num_classes):
        super(SpatialCNNTransformer, self).__init__()
        self.cnn = nn.Sequential(
            nn.Conv2d(1, 64, (1, 16), padding='same'),
            nn.ReLU(),
            nn.AvgPool2d((1, 32)),
            nn.Conv2d(64, 64, (1, 15)),
            nn.ReLU()
        )
        self.embedding = nn.Linear(64, d_model)
        self.pos_encoder = PositionalEncoding(d_model)
        self.transformer = nn.Sequential(*[TransformerBlock(d_model, nhead) for _ in range(3)])
        self.fc = nn.Linear(d_model, num_classes)

    def forward(self, x):  # x shape: (batch, 1, channels, time)
        x = self.cnn(x).squeeze(3).permute(2, 0, 1)
        x = self.embedding(x)
        x = self.pos_encoder(x)
        x = self.transformer(x)
        x = x.mean(dim=0)
        return self.fc(x)

# %% [markdown]
# # <font color="pink"> Temporal CNN Transformer</font>
#
#   <font color="lightblue">*In the temporal implementation of the CNN + Transformer
#  model (t-Ctrans, Fig 3d), the CNN module included one
#  convolutional layer and one average pooling layer. The con
# volutional layer used 64 kernels with the size of 64 × 1(chan
# nel × time points) to extract EEG spatial information, and
#  adopted the SAME padding. The average pooling layer had
#  the pooling size of 1 × 8. After the average pooling layer,
#  we transposed the features.*</font>

# %%
# Uses CNN to help extract spatial features per time point, then model time dynamics
class TemporalCNNTransformer(nn.Module):
    def __init__(self, input_size, d_model, nhead, num_classes):
        super(TemporalCNNTransformer, self).__init__()
        self.cnn = nn.Sequential(
            nn.Conv2d(1, 64, kernel_size=(64, 1), padding='same'),
            nn.ReLU(),
            nn.AvgPool2d((1, 8))
        )
        self.embedding = nn.Linear(64, d_model)
        self.pos_encoder = PositionalEncoding(d_model)
        self.transformer = nn.Sequential(*[TransformerBlock(d_model, nhead) for _ in range(3)])
        self.fc = nn.Linear(d_model, num_classes)

    def forward(self, x):  # x shape: (batch, 1, channels, time)
        x = self.cnn(x)               # → (B, 64, 1, T_new)
        x = x.mean(dim=2)             # → (B, 64, T_new)
        x = x.permute(2, 0, 1)        # (time, batch, features)
        x = self.embedding(x)
        x = self.pos_encoder(x)
        x = self.transformer(x)
        x = x.mean(dim=0)
        return self.fc(x)

# %% [markdown]
# # <font color="pink"> FusionCNNTransformer</font>

# %%
# Combine best both spatial and temporal CNN Transformer
class FusionCNNTransformer(nn.Module):
    def __init__(self, input_size, d_model, nhead, num_classes):
        super(FusionCNNTransformer, self).__init__()
        self.s_cnn = SpatialCNNTransformer(input_size, d_model, nhead, num_classes)
        self.t_cnn = TemporalCNNTransformer(input_size, d_model, nhead, num_classes)
        self.fc = nn.Linear(num_classes * 2, num_classes)

    def forward(self, x):
        spatial_out = self.s_cnn(x)
        temporal_out = self.t_cnn(x)
        fusion = torch.cat((spatial_out, temporal_out), dim=1)
        return self.fc(fusion)

# %% [markdown]
# ---
#
# # <font color="pink"> Przygotowanie danych do treningu w PyTorch</font>

# %%
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset, DataLoader

class EEGDataset(Dataset):
  def __init__(self, X, y, cnn_mode=False):
    self.X = torch.tensor(X, dtype=torch.float32)
    if cnn_mode:
      # Bo modele CNN potrzebuja 4D na feature
      self.X = self.X.unsqueeze(1)
    self.y = torch.tensor(y, dtype=torch.long)
  def __len__(self):
      return len(self.X)
  def __getitem__(self, idx):
    return self.X[idx], self.y[idx]

# %% [markdown]
# ---
#
# # <font color="pink">Implentacja Within-Individual Training</font>

# %%
# !pip install torchmetrics
# !pip install mne
# Out:
# Requirement already satisfied: torchmetrics in /usr/local/lib/python3.11/dist-packages (1.7.1)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.11/dist-packages (from torchmetrics) (2.0.2)
# Requirement already satisfied: packaging>17.1 in /usr/local/lib/python3.11/dist-packages (from torchmetrics) (24.2)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from torchmetrics) (2.6.0+cu124)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /usr/local/lib/python3.11/dist-packages (from torchmetrics) (0.14.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (75.2.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.11/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (4.13.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->torchmetrics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->torchmetrics) (3.0.2)
# Requirement already satisfied: mne in /usr/local/lib/python3.11/dist-packages (1.9.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from mne) (4.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from mne) (3.1.6)
# Requirement already satisfied: lazy-loader>=0.3 in /usr/local/lib/python3.11/dist-packages (from mne) (0.4)
# Requirement already satisfied: matplotlib>=3.6 in /usr/local/lib/python3.11/dist-packages (from mne) (3.10.0)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.11/dist-packages (from mne) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from mne) (24.2)
# Requirement already satisfied: pooch>=1.5 in /usr/local/lib/python3.11/dist-packages (from mne) (1.8.2)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.11/dist-packages (from mne) (1.14.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from mne) (4.67.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6->mne) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6->mne) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6->mne) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6->mne) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6->mne) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6->mne) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6->mne) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.5->mne) (4.3.7)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.5->mne) (2.32.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->mne) (3.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.6->mne) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2025.1.31)

# %% [markdown]
# *Training Parameter Settings:*
# <font color="lightblue">
# * *Empirically, the number of
#  head in each multi-head attention layer was set to 8 [25].*
# * *The dropout rate was set to 0.3.*
# * *The parameter of the position-wise fully connected feed-forward layer with a ReLU activation was set to 512.*
# * *The weight attenuation was 0.0001.*
# * *All the models used the Adam optimizer. The training epoch was set
#  to 50.*
# * *We set the number of training epochs to 10*
# * *The EEG data were transformed into 3D tensors (N, C, T), where N is the number of trials, C is the number of channels, and T is the time points.*
# * *In our Transformer-based models,
#  we set dk = dv = 64, which was the same size as EEG
#  channel numbers.*</font>

# %%
import mne
import os
import csv
import numpy as np
from torchmetrics.classification import Accuracy


preprocessed_data_dir ="/content/drive/My Drive/EEG_Data/Physionet"
d_model = 64
nhead = 8
num_classes = 2
batch_size = 32
num_epochs = 50
weight_decay=1e-4
cnn_models = {"SpatialCNNTransformer", "TemporalCNNTransformer", "FusionCNNTransformer"}

def load_subject_data(file_path) ->tuple[np.ndarray, np.ndarray]:
    epochs = mne.read_epochs(file_path, preload=True)
    """
    Number of epochs, channels, n_times -> Liczba punktów czasowych w jednym epizodzie EEG (czyli długość sygnału w czasie).
                                          Dla danych 3-sekundowych:
                                          EEG było próbkowane z częstotliwością 160 Hz

                                          3 sekundy × 160 Hz = 480 punktów

                                          Więc: n_times = 480

                                          Dla danych 6-sekundowych:
                                          6 sekundy × 160 Hz = 960 punktów

                                          Więc: n_times = 960
    """
    X = epochs.get_data()

    # Labels
    y = epochs.events[:, -1]

    # Labels should be numered 0, 1, 2 ...
    y = np.array([0 if label == 2 else 1 for label in y])
    return X, y


def train_model(model, train_loader, test_loader, device, lr):
  model.to(device)
  optimizer = torch.optim.Adam(model.parameters(), lr=7e-4, weight_decay=1e-4)
  criterion = torch.nn.CrossEntropyLoss()

  for epoch in range(num_epochs):
    model.train()
    total_loss = 0
    for X_batch, y_batch in train_loader:
      X_batch, y_batch = X_batch.to(device), y_batch.to(device)
      optimizer.zero_grad()
      output = model(X_batch)
      loss = criterion(output, y_batch)
      loss.backward()
      optimizer.step()
      total_loss += loss.item()
    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {total_loss:.4f}")


def evaluate_model(model, test_loader, device)-> float:
  acc = Accuracy(task='binary').to(device)
  model.eval()

  with torch.no_grad():
    for X_batch, y_batch in test_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        output = model(X_batch)
        preds = torch.argmax(output, dim=1)
        acc.update(preds, y_batch)

  return acc.compute().item()


def train_within_individual(model_class, learning_rate):
  device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
  results = []

  for subj_folder in os.listdir(preprocessed_data_dir):
      subj_folder_path = os.path.join(preprocessed_data_dir, subj_folder)
      file_path = os.path.join(subj_folder_path, f"PA{subj_folder[1:]}-3s-epo.fif")

      if not os.path.exists(file_path):
        continue

      print(f"\nTraining model for subject {subj_folder}...")
      X, y = load_subject_data(file_path)

      X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

      cnn_mode = model_class.__name__ in cnn_models

      train_dataset = EEGDataset(X_train, y_train, cnn_mode)
      test_dataset = EEGDataset(X_test, y_test, cnn_mode)

      train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
      test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

      model = model_class(input_size=X.shape[2], d_model=d_model, nhead=nhead, num_classes=num_classes)
      train_model(model, train_loader=train_loader, test_loader=test_loader, device=device, lr=learning_rate)

      accuracy = evaluate_model(model, test_loader, device)
      print(f"Accuracy for subject {subj_folder}: {accuracy * 100:.2f}%")

      # Append subject and accuracy to the results list
      results.append([subj_folder, accuracy * 100])

      # Save the model's state_dict
      model_save_path = f"trained_model_{subj_folder}.pth"
      torch.save(model.state_dict(), model_save_path)
      print(f"Model for subject {subj_folder} saved to {model_save_path}")

      output_csv = f"/content/drive/My Drive/EEG_Data/Physionet/subject_accuracies_{model_class.__name__ }.csv"

      # Save the results to a CSV file
      with open(output_csv, mode='w', newline='') as f:
          writer = csv.writer(f)
          writer.writerow(["Subject", "Accuracy"])
          writer.writerows(results)
      print(f"\nResults saved to {output_csv}")

# %%
train_within_individual(SpatialTransformer, learning_rate=7e-4)
# Out:
# Training model for subject S034...
# Reading /content/drive/My Drive/EEG_Data/Physionet/S034/PA034-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Loaded data shape: (42, 64, 481)
# Epoch 1/50, Loss: 0.6870
# Epoch 2/50, Loss: 0.6855
# Epoch 3/50, Loss: 0.4665
# Epoch 4/50, Loss: 0.4633
# Epoch 5/50, Loss: 0.3765
# Epoch 6/50, Loss: 0.2730
# Epoch 7/50, Loss: 0.2369
# Epoch 8/50, Loss: 0.2120
# Epoch 9/50, Loss: 0.1635
# Epoch 10/50, Loss: 0.1145
# Epoch 11/50, Loss: 0.0926
# Epoch 12/50, Loss: 0.0746
# Epoch 13/50, Loss: 0.0458
# Epoch 14/50, Loss: 0.0314
# Epoch 15/50, Loss: 0.0229
# Epoch 16/50, Loss: 0.0151
# Epoch 17/50, Loss: 0.0096
# Epoch 18/50, Loss: 0.0067
# Epoch 19/50, Loss: 0.0053
# Epoch 20/50, Loss: 0.0046
# Epoch 21/50, Loss: 0.0042
# Epoch 22/50, Loss: 0.0040
# Epoch 23/50, Loss: 0.0036
# Epoch 24/50, Loss: 0.0032
# Epoch 25/50, Loss: 0.0028
# Epoch 26/50, Loss: 0.0024
# Epoch 27/50, Loss: 0.0021
# Epoch 28/50, Loss: 0.0019
# Epoch 29/50, Loss: 0.0017
# Epoch 30/50, Loss: 0.0016
# Epoch 31/50, Loss: 0.0015
# Epoch 32/50, Loss: 0.0014
# Epoch 33/50, Loss: 0.0014
# Epoch 34/50, Loss: 0.0013
# Epoch 35/50, Loss: 0.0013
# Epoch 36/50, Loss: 0.0012
# Epoch 37/50, Loss: 0.0012
# Epoch 38/50, Loss: 0.0011
# Epoch 39/50, Loss: 0.0011
# Epoch 40/50, Loss: 0.0011
# Epoch 41/50, Loss: 0.0011
# Epoch 42/50, Loss: 0.0010
# Epoch 43/50, Loss: 0.0010
# Epoch 44/50, Loss: 0.0010
# Epoch 45/50, Loss: 0.0010
# Epoch 46/50, Loss: 0.0010
# Epoch 47/50, Loss: 0.0010
# Epoch 48/50, Loss: 0.0009
# Epoch 49/50, Loss: 0.0009
# Epoch 50/50, Loss: 0.0009
# Accuracy for subject S034: 61.54%
# Model for subject S034 saved to trained_model_S034.pth
#
# Results saved to /content/drive/My Drive/EEG_Data/Physionet/subject_accuracies.csv
#
# Training model for subject S033...
# Reading /content/drive/My Drive/EEG_Data/Physionet/S033/PA033-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Loaded data shape: (42, 64, 481)
# Epoch 1/50, Loss: 0.7444
# Epoch 2/50, Loss: 0.6433
# Epoch 3/50, Loss: 0.4747
# Epoch 4/50, Loss: 0.3113
# Epoch 5/50, Loss: 0.2411
# Epoch 6/50, Loss: 0.1890
# Epoch 7/50, Loss: 0.1219
# Epoch 8/50, Loss: 0.0658
# Epoch 9/50, Loss: 0.0354
# Epoch 10/50, Loss: 0.0208
# Epoch 11/50, Loss: 0.0138
# Epoch 12/50, Loss: 0.0101
# Epoch 13/50, Loss: 0.0078
# Epoch 14/50, Loss: 0.0064
# Epoch 15/50, Loss: 0.0054
# Epoch 16/50, Loss: 0.0046
# Epoch 17/50, Loss: 0.0040
# Epoch 18/50, Loss: 0.0035
# Epoch 19/50, Loss: 0.0032
# Epoch 20/50, Loss: 0.0029
# Epoch 21/50, Loss: 0.0027
# Epoch 22/50, Loss: 0.0025
# Epoch 23/50, Loss: 0.0023
# Epoch 24/50, Loss: 0.0022
# Epoch 25/50, Loss: 0.0021
# Epoch 26/50, Loss: 0.0020
# Epoch 27/50, Loss: 0.0019
# Epoch 28/50, Loss: 0.0019
# Epoch 29/50, Loss: 0.0018
# Epoch 30/50, Loss: 0.0018
# Epoch 31/50, Loss: 0.0017
# Epoch 32/50, Loss: 0.0017
# Epoch 33/50, Loss: 0.0016
# Epoch 34/50, Loss: 0.0016
# Epoch 35/50, Loss: 0.0015
# Epoch 36/50, Loss: 0.0015
# Epoch 37/50, Loss: 0.0015
# Epoch 38/50, Loss: 0.0015
# Epoch 39/50, Loss: 0.0014
# Epoch 40/50, Loss: 0.0014
# Epoch 41/50, Loss: 0.0014
# Epoch 42/50, Loss: 0.0014
# Epoch 43/50, Loss: 0.0013
# Epoch 44/50, Loss: 0.0013
# Epoch 45/50, Loss: 0.0013
# Epoch 46/50, Loss: 0.0013
# Epoch 47/50, Loss: 0.0013
# Epoch 48/50, Loss: 0.0012
# Epoch 49/50, Loss: 0.0012
# Epoch 50/50, Loss: 0.0012
# Accuracy for subject S033: 84.62%
# Model for subject S033 saved to trained_model_S033.pth
#
# Results saved to /content/drive/My Drive/EEG_Data/Physionet/subject_accuracies.csv
#
# Training model for subject S032...
# Reading /content/drive/My Drive/EEG_Data/Physionet/S032/PA032-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Loaded data shape: (42, 64, 481)
# Epoch 1/50, Loss: 0.7746
# Epoch 2/50, Loss: 0.8046
# Epoch 3/50, Loss: 0.5753
# Epoch 4/50, Loss: 0.5564
# Epoch 5/50, Loss: 0.5239
# Epoch 6/50, Loss: 0.4229
# Epoch 7/50, Loss: 0.3644
# Epoch 8/50, Loss: 0.3424
# Epoch 9/50, Loss: 0.2889
# Epoch 10/50, Loss: 0.2135
# Epoch 11/50, Loss: 0.1639
# Epoch 12/50, Loss: 0.1302
# Epoch 13/50, Loss: 0.0857
# Epoch 14/50, Loss: 0.0515
# Epoch 15/50, Loss: 0.0338
# Epoch 16/50, Loss: 0.0216
# Epoch 17/50, Loss: 0.0152
# Epoch 18/50, Loss: 0.0115
# Epoch 19/50, Loss: 0.0088
# Epoch 20/50, Loss: 0.0067
# Epoch 21/50, Loss: 0.0052
# Epoch 22/50, Loss: 0.0042
# Epoch 23/50, Loss: 0.0035
# Epoch 24/50, Loss: 0.0030
# Epoch 25/50, Loss: 0.0026
# Epoch 26/50, Loss: 0.0023
# Epoch 27/50, Loss: 0.0021
# Epoch 28/50, Loss: 0.0019
# Epoch 29/50, Loss: 0.0018
# Epoch 30/50, Loss: 0.0017
# Epoch 31/50, Loss: 0.0016
# Epoch 32/50, Loss: 0.0015
# Epoch 33/50, Loss: 0.0015
# Epoch 34/50, Loss: 0.0014
# Epoch 35/50, Loss: 0.0014
# Epoch 36/50, Loss: 0.0013
# Epoch 37/50, Loss: 0.0013
# Epoch 38/50, Loss: 0.0012
# Epoch 39/50, Loss: 0.0012
# Epoch 40/50, Loss: 0.0012
# Epoch 41/50, Loss: 0.0012
# Epoch 42/50, Loss: 0.0011
# Epoch 43/50, Loss: 0.0011
# Epoch 44/50, Loss: 0.0011
# Epoch 45/50, Loss: 0.0011
# Epoch 46/50, Loss: 0.0010
# Epoch 47/50, Loss: 0.0010
# Epoch 48/50, Loss: 0.0010
# Epoch 49/50, Loss: 0.0010
# Epoch 50/50, Loss: 0.0010
# Accuracy for subject S032: 53.85%
# Model for subject S032 saved to trained_model_S032.pth
#
# Results saved to /content/drive/My Drive/EEG_Data/Physionet/subject_accuracies.csv
#
# Training model for subject S031...
# Reading /content/drive/My Drive/EEG_Data/Physionet/S031/PA031-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Loaded data shape: (42, 64, 481)
# Epoch 1/50, Loss: 0.7048
# Epoch 2/50, Loss: 0.5254
# Epoch 3/50, Loss: 0.4213
# Epoch 4/50, Loss: 0.2825
# Epoch 5/50, Loss: 0.1752
# Epoch 6/50, Loss: 0.0942
# Epoch 7/50, Loss: 0.0501
# Epoch 8/50, Loss: 0.0228
# Epoch 9/50, Loss: 0.0121
# Epoch 10/50, Loss: 0.0081
# Epoch 11/50, Loss: 0.0062
# Epoch 12/50, Loss: 0.0051
# Epoch 13/50, Loss: 0.0043
# Epoch 14/50, Loss: 0.0037
# Epoch 15/50, Loss: 0.0033
# Epoch 16/50, Loss: 0.0029
# Epoch 17/50, Loss: 0.0027
# Epoch 18/50, Loss: 0.0025
# Epoch 19/50, Loss: 0.0023
# Epoch 20/50, Loss: 0.0022
# Epoch 21/50, Loss: 0.0021
# Epoch 22/50, Loss: 0.0020
# Epoch 23/50, Loss: 0.0019
# Epoch 24/50, Loss: 0.0018
# Epoch 25/50, Loss: 0.0018
# Epoch 26/50, Loss: 0.0017
# Epoch 27/50, Loss: 0.0017
# Epoch 28/50, Loss: 0.0016
# Epoch 29/50, Loss: 0.0016
# Epoch 30/50, Loss: 0.0015
# Epoch 31/50, Loss: 0.0015
# Epoch 32/50, Loss: 0.0015
# Epoch 33/50, Loss: 0.0014
# Epoch 34/50, Loss: 0.0014
# Epoch 35/50, Loss: 0.0014
# Epoch 36/50, Loss: 0.0014
# Epoch 37/50, Loss: 0.0013
# Epoch 38/50, Loss: 0.0013
# Epoch 39/50, Loss: 0.0013
# Epoch 40/50, Loss: 0.0013
# Epoch 41/50, Loss: 0.0012
# Epoch 42/50, Loss: 0.0012
# Epoch 43/50, Loss: 0.0012
# Epoch 44/50, Loss: 0.0012
# Epoch 45/50, Loss: 0.0012
# Epoch 46/50, Loss: 0.0012
# Epoch 47/50, Loss: 0.0011
# Epoch 48/50, Loss: 0.0011
# Epoch 49/50, Loss: 0.0011
# Epoch 50/50, Loss: 0.0011
# Accuracy for subject S031: 76.92%
# Model for subject S031 saved to trained_model_S031.pth
#
# Results saved to /content/drive/My Drive/EEG_Data/Physionet/subject_accuracies.csv
#
# Training model for subject S030...
# Reading /content/drive/My Drive/EEG_Data/Physionet/S030/PA030-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Loaded data shape: (42, 64, 481)
# Epoch 1/50, Loss: 0.7111
# Epoch 2/50, Loss: 0.7560
# Epoch 3/50, Loss: 0.5093
# Epoch 4/50, Loss: 0.4319
# Epoch 5/50, Loss: 0.4140
# Epoch 6/50, Loss: 0.3189
# Epoch 7/50, Loss: 0.2253
# Epoch 8/50, Loss: 0.1799
# Epoch 9/50, Loss: 0.1439
# Epoch 10/50, Loss: 0.0923
# Epoch 11/50, Loss: 0.0519
# Epoch 12/50, Loss: 0.0322
# Epoch 13/50, Loss: 0.0222
# Epoch 14/50, Loss: 0.0152
# Epoch 15/50, Loss: 0.0105
# Epoch 16/50, Loss: 0.0078
# Epoch 17/50, Loss: 0.0061
# Epoch 18/50, Loss: 0.0051
# Epoch 19/50, Loss: 0.0044
# Epoch 20/50, Loss: 0.0039
# Epoch 21/50, Loss: 0.0036
# Epoch 22/50, Loss: 0.0033
# Epoch 23/50, Loss: 0.0030
# Epoch 24/50, Loss: 0.0029
# Epoch 25/50, Loss: 0.0027
# Epoch 26/50, Loss: 0.0026
# Epoch 27/50, Loss: 0.0025
# Epoch 28/50, Loss: 0.0024
# Epoch 29/50, Loss: 0.0023
# Epoch 30/50, Loss: 0.0022
# Epoch 31/50, Loss: 0.0021
# Epoch 32/50, Loss: 0.0021
# Epoch 33/50, Loss: 0.0020
# Epoch 34/50, Loss: 0.0020
# Epoch 35/50, Loss: 0.0019
# Epoch 36/50, Loss: 0.0019
# Epoch 37/50, Loss: 0.0018
# Epoch 38/50, Loss: 0.0018
# Epoch 39/50, Loss: 0.0018
# Epoch 40/50, Loss: 0.0017
# Epoch 41/50, Loss: 0.0017
# Epoch 42/50, Loss: 0.0017
# Epoch 43/50, Loss: 0.0017
# Epoch 44/50, Loss: 0.0016
# Epoch 45/50, Loss: 0.0016
# Epoch 46/50, Loss: 0.0016
# Epoch 47/50, Loss: 0.0016
# Epoch 48/50, Loss: 0.0016
# Epoch 49/50, Loss: 0.0015
# Epoch 50/50, Loss: 0.0015
# Accuracy for subject S030: 69.23%
# Model for subject S030 saved to trained_model_S030.pth
#
# Results saved to /content/drive/My Drive/EEG_Data/Physionet/subject_accuracies.csv
#
# Training model for subject S029...
# Reading /content/drive/My Drive/EEG_Data/Physionet/S029/PA029-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Loaded data shape: (42, 64, 481)
# Epoch 1/50, Loss: 0.7481
# Epoch 2/50, Loss: 0.4804
# Epoch 3/50, Loss: 0.4316
# Epoch 4/50, Loss: 0.4009
# Epoch 5/50, Loss: 0.3375
# Epoch 6/50, Loss: 0.2860
# Epoch 7/50, Loss: 0.2529
# Epoch 8/50, Loss: 0.2251
# Epoch 9/50, Loss: 0.2082
# Epoch 10/50, Loss: 0.1941
# Epoch 11/50, Loss: 0.1733
# Epoch 12/50, Loss: 0.1530
# Epoch 13/50, Loss: 0.1376
# Epoch 14/50, Loss: 0.1247
# Epoch 15/50, Loss: 0.1082
# Epoch 16/50, Loss: 0.0866
# Epoch 17/50, Loss: 0.0663
# Epoch 18/50, Loss: 0.0516
# Epoch 19/50, Loss: 0.0356
# Epoch 20/50, Loss: 0.0199
# Epoch 21/50, Loss: 0.0115
# Epoch 22/50, Loss: 0.0076
# Epoch 23/50, Loss: 0.0055
# Epoch 24/50, Loss: 0.0042
# Epoch 25/50, Loss: 0.0033
# Epoch 26/50, Loss: 0.0028
# Epoch 27/50, Loss: 0.0024
# Epoch 28/50, Loss: 0.0022
# Epoch 29/50, Loss: 0.0020
# Epoch 30/50, Loss: 0.0018
# Epoch 31/50, Loss: 0.0017
# Epoch 32/50, Loss: 0.0016
# Epoch 33/50, Loss: 0.0016
# Epoch 34/50, Loss: 0.0015
# Epoch 35/50, Loss: 0.0014
# Epoch 36/50, Loss: 0.0014
# Epoch 37/50, Loss: 0.0013
# Epoch 38/50, Loss: 0.0013
# Epoch 39/50, Loss: 0.0012
# Epoch 40/50, Loss: 0.0012
# Epoch 41/50, Loss: 0.0012
# Epoch 42/50, Loss: 0.0011
# Epoch 43/50, Loss: 0.0011
# Epoch 44/50, Loss: 0.0011
# Epoch 45/50, Loss: 0.0010
# Epoch 46/50, Loss: 0.0010
# Epoch 47/50, Loss: 0.0010
# Epoch 48/50, Loss: 0.0010
# Epoch 49/50, Loss: 0.0010
# Epoch 50/50, Loss: 0.0010
# Accuracy for subject S029: 30.77%
# Model for subject S029 saved to trained_model_S029.pth
#
# Results saved to /content/drive/My Drive/EEG_Data/Physionet/subject_accuracies.csv
#
# Training model for subject S028...
# Reading /content/drive/My Drive/EEG_Data/Physionet/S028/PA028-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Loaded data shape: (42, 64, 481)
# Epoch 1/50, Loss: 0.7697
# Epoch 2/50, Loss: 0.7079
# Epoch 3/50, Loss: 0.5512
# Epoch 4/50, Loss: 0.5108
# Epoch 5/50, Loss: 0.4766
# Epoch 6/50, Loss: 0.3958
# Epoch 7/50, Loss: 0.3231
# Epoch 8/50, Loss: 0.2748
# Epoch 9/50, Loss: 0.2138
# Epoch 10/50, Loss: 0.1454
# Epoch 11/50, Loss: 0.0984
# Epoch 12/50, Loss: 0.0658
# Epoch 13/50, Loss: 0.0390
# Epoch 14/50, Loss: 0.0241
# Epoch 15/50, Loss: 0.0167
# Epoch 16/50, Loss: 0.0123
# Epoch 17/50, Loss: 0.0093
# Epoch 18/50, Loss: 0.0074
# Epoch 19/50, Loss: 0.0061
# Epoch 20/50, Loss: 0.0053
# Epoch 21/50, Loss: 0.0047
# Epoch 22/50, Loss: 0.0043
# Epoch 23/50, Loss: 0.0039
# Epoch 24/50, Loss: 0.0037
# Epoch 25/50, Loss: 0.0035
# Epoch 26/50, Loss: 0.0033
# Epoch 27/50, Loss: 0.0031
# Epoch 28/50, Loss: 0.0030
# Epoch 29/50, Loss: 0.0029
# Epoch 30/50, Loss: 0.0028
# Epoch 31/50, Loss: 0.0027
# Epoch 32/50, Loss: 0.0026
# Epoch 33/50, Loss: 0.0025
# Epoch 34/50, Loss: 0.0025
# Epoch 35/50, Loss: 0.0024
# Epoch 36/50, Loss: 0.0024
# Epoch 37/50, Loss: 0.0023
# Epoch 38/50, Loss: 0.0022
# Epoch 39/50, Loss: 0.0022
# Epoch 40/50, Loss: 0.0022
# Epoch 41/50, Loss: 0.0021
# Epoch 42/50, Loss: 0.0021
# Epoch 43/50, Loss: 0.0020
# Epoch 44/50, Loss: 0.0020
# Epoch 45/50, Loss: 0.0020
# Epoch 46/50, Loss: 0.0019
# Epoch 47/50, Loss: 0.0019
# Epoch 48/50, Loss: 0.0019
# Epoch 49/50, Loss: 0.0019
# Epoch 50/50, Loss: 0.0018
# Accuracy for subject S028: 46.15%
# Model for subject S028 saved to trained_model_S028.pth
#
# Results saved to /content/drive/My Drive/EEG_Data/Physionet/subject_accuracies.csv
#
# Training model for subject S027...
# Reading /content/drive/My Drive/EEG_Data/Physionet/S027/PA027-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Loaded data shape: (42, 64, 481)
# Epoch 1/50, Loss: 0.6594
# Epoch 2/50, Loss: 0.4690
# Epoch 3/50, Loss: 0.3297
# Epoch 4/50, Loss: 0.2246
# Epoch 5/50, Loss: 0.1664
# Epoch 6/50, Loss: 0.1195
# Epoch 7/50, Loss: 0.0739
# Epoch 8/50, Loss: 0.0425
# Epoch 9/50, Loss: 0.0228
# Epoch 10/50, Loss: 0.0127
# Epoch 11/50, Loss: 0.0079
# Epoch 12/50, Loss: 0.0056
# Epoch 13/50, Loss: 0.0043
# Epoch 14/50, Loss: 0.0035
# Epoch 15/50, Loss: 0.0030
# Epoch 16/50, Loss: 0.0027
# Epoch 17/50, Loss: 0.0025
# Epoch 18/50, Loss: 0.0023
# Epoch 19/50, Loss: 0.0022
# Epoch 20/50, Loss: 0.0020
# Epoch 21/50, Loss: 0.0019
# Epoch 22/50, Loss: 0.0018
# Epoch 23/50, Loss: 0.0017
# Epoch 24/50, Loss: 0.0015
# Epoch 25/50, Loss: 0.0014
# Epoch 26/50, Loss: 0.0014
# Epoch 27/50, Loss: 0.0013
# Epoch 28/50, Loss: 0.0012
# Epoch 29/50, Loss: 0.0012
# Epoch 30/50, Loss: 0.0011
# Epoch 31/50, Loss: 0.0011
# Epoch 32/50, Loss: 0.0011
# Epoch 33/50, Loss: 0.0010
# Epoch 34/50, Loss: 0.0010
# Epoch 35/50, Loss: 0.0010
# Epoch 36/50, Loss: 0.0010
# Epoch 37/50, Loss: 0.0009
# Epoch 38/50, Loss: 0.0009
# Epoch 39/50, Loss: 0.0009
# Epoch 40/50, Loss: 0.0009
# Epoch 41/50, Loss: 0.0009
# Epoch 42/50, Loss: 0.0009
# Epoch 43/50, Loss: 0.0008
# Epoch 44/50, Loss: 0.0008
# Epoch 45/50, Loss: 0.0008
# Epoch 46/50, Loss: 0.0008
# Epoch 47/50, Loss: 0.0008
# Epoch 48/50, Loss: 0.0008
# Epoch 49/50, Loss: 0.0008
# Epoch 50/50, Loss: 0.0008
# Accuracy for subject S027: 38.46%
# Model for subject S027 saved to trained_model_S027.pth
#
# Results saved to /content/drive/My Drive/EEG_Data/Physionet/subject_accuracies.csv
#
# Training model for subject S026...
# Reading /content/drive/My Drive/EEG_Data/Physionet/S026/PA026-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Loaded data shape: (42, 64, 481)
# Epoch 1/50, Loss: 0.6788
# Epoch 2/50, Loss: 0.6078
# Epoch 3/50, Loss: 0.4050
# Epoch 4/50, Loss: 0.3663
# Epoch 5/50, Loss: 0.2541
# Epoch 6/50, Loss: 0.1424
# Epoch 7/50, Loss: 0.0873
# Epoch 8/50, Loss: 0.0552
# Epoch 9/50, Loss: 0.0316
# Epoch 10/50, Loss: 0.0176
# Epoch 11/50, Loss: 0.0108
# Epoch 12/50, Loss: 0.0075
# Epoch 13/50, Loss: 0.0056
# Epoch 14/50, Loss: 0.0045
# Epoch 15/50, Loss: 0.0038
# Epoch 16/50, Loss: 0.0033
# Epoch 17/50, Loss: 0.0030
# Epoch 18/50, Loss: 0.0027
# Epoch 19/50, Loss: 0.0025
# Epoch 20/50, Loss: 0.0023
# Epoch 21/50, Loss: 0.0022
# Epoch 22/50, Loss: 0.0020
# Epoch 23/50, Loss: 0.0019
# Epoch 24/50, Loss: 0.0019
# Epoch 25/50, Loss: 0.0018
# Epoch 26/50, Loss: 0.0017
# Epoch 27/50, Loss: 0.0017
# Epoch 28/50, Loss: 0.0016
# Epoch 29/50, Loss: 0.0016
# Epoch 30/50, Loss: 0.0015
# Epoch 31/50, Loss: 0.0015
# Epoch 32/50, Loss: 0.0014
# Epoch 33/50, Loss: 0.0014
# Epoch 34/50, Loss: 0.0014
# Epoch 35/50, Loss: 0.0014
# Epoch 36/50, Loss: 0.0013
# Epoch 37/50, Loss: 0.0013
# Epoch 38/50, Loss: 0.0013
# Epoch 39/50, Loss: 0.0013
# Epoch 40/50, Loss: 0.0012
# Epoch 41/50, Loss: 0.0012
# Epoch 42/50, Loss: 0.0012
# Epoch 43/50, Loss: 0.0012
# Epoch 44/50, Loss: 0.0012
# Epoch 45/50, Loss: 0.0011
# Epoch 46/50, Loss: 0.0011
# Epoch 47/50, Loss: 0.0011
# Epoch 48/50, Loss: 0.0011
# Epoch 49/50, Loss: 0.0011
# Epoch 50/50, Loss: 0.0011
# Accuracy for subject S026: 46.15%
# Model for subject S026 saved to trained_model_S026.pth
#
# Results saved to /content/drive/My Drive/EEG_Data/Physionet/subject_accuracies.csv
#
# Training model for subject S025...
# Reading /content/drive/My Drive/EEG_Data/Physionet/S025/PA025-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Loaded data shape: (42, 64, 481)
# Epoch 1/50, Loss: 0.8896
# Epoch 2/50, Loss: 0.6862
# Epoch 3/50, Loss: 0.4834
# Epoch 4/50, Loss: 0.4178
# Epoch 5/50, Loss: 0.3047
# Epoch 6/50, Loss: 0.2031
# Epoch 7/50, Loss: 0.1429
# Epoch 8/50, Loss: 0.0868
# Epoch 9/50, Loss: 0.0419
# Epoch 10/50, Loss: 0.0207
# Epoch 11/50, Loss: 0.0126
# Epoch 12/50, Loss: 0.0086
# Epoch 13/50, Loss: 0.0064
# Epoch 14/50, Loss: 0.0049
# Epoch 15/50, Loss: 0.0039
# Epoch 16/50, Loss: 0.0032
# Epoch 17/50, Loss: 0.0027
# Epoch 18/50, Loss: 0.0024
# Epoch 19/50, Loss: 0.0021
# Epoch 20/50, Loss: 0.0019
# Epoch 21/50, Loss: 0.0018
# Epoch 22/50, Loss: 0.0017
# Epoch 23/50, Loss: 0.0016
# Epoch 24/50, Loss: 0.0015
# Epoch 25/50, Loss: 0.0014
# Epoch 26/50, Loss: 0.0014
# Epoch 27/50, Loss: 0.0013
# Epoch 28/50, Loss: 0.0013
# Epoch 29/50, Loss: 0.0012
# Epoch 30/50, Loss: 0.0012
# Epoch 31/50, Loss: 0.0012
# Epoch 32/50, Loss: 0.0011
# Epoch 33/50, Loss: 0.0011
# Epoch 34/50, Loss: 0.0011
# Epoch 35/50, Loss: 0.0011
# Epoch 36/50, Loss: 0.0010
# Epoch 37/50, Loss: 0.0010
# Epoch 38/50, Loss: 0.0010
# Epoch 39/50, Loss: 0.0010
# Epoch 40/50, Loss: 0.0010
# Epoch 41/50, Loss: 0.0010
# Epoch 42/50, Loss: 0.0009
# Epoch 43/50, Loss: 0.0009
# Epoch 44/50, Loss: 0.0009
# Epoch 45/50, Loss: 0.0009
# Epoch 46/50, Loss: 0.0009
# Epoch 47/50, Loss: 0.0009
# Epoch 48/50, Loss: 0.0009
# Epoch 49/50, Loss: 0.0009
# Epoch 50/50, Loss: 0.0008
# Accuracy for subject S025: 30.77%
# Model for subject S025 saved to trained_model_S025.pth
#
# Results saved to /content/drive/My Drive/EEG_Data/Physionet/subject_accuracies.csv
#
# Training model for subject S024...
# Reading /content/drive/My Drive/EEG_Data/Physionet/S024/PA024-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Loaded data shape: (42, 64, 481)
# Epoch 1/50, Loss: 0.6839
# Epoch 2/50, Loss: 0.8745
# Epoch 3/50, Loss: 0.5754
# Epoch 4/50, Loss: 0.5213
# Epoch 5/50, Loss: 0.5452
# Epoch 6/50, Loss: 0.4272
# Epoch 7/50, Loss: 0.3152
# Epoch 8/50, Loss: 0.2816
# Epoch 9/50, Loss: 0.2505
# Epoch 10/50, Loss: 0.1803
# Epoch 11/50, Loss: 0.1045
# Epoch 12/50, Loss: 0.0667
# Epoch 13/50, Loss: 0.0513
# Epoch 14/50, Loss: 0.0383
# Epoch 15/50, Loss: 0.0263
# Epoch 16/50, Loss: 0.0183
# Epoch 17/50, Loss: 0.0134
# Epoch 18/50, Loss: 0.0098
# Epoch 19/50, Loss: 0.0073
# Epoch 20/50, Loss: 0.0056
# Epoch 21/50, Loss: 0.0045
# Epoch 22/50, Loss: 0.0038
# Epoch 23/50, Loss: 0.0033
# Epoch 24/50, Loss: 0.0029
# Epoch 25/50, Loss: 0.0027
# Epoch 26/50, Loss: 0.0024
# Epoch 27/50, Loss: 0.0023
# Epoch 28/50, Loss: 0.0021
# Epoch 29/50, Loss: 0.0020
# Epoch 30/50, Loss: 0.0019
# Epoch 31/50, Loss: 0.0018
# Epoch 32/50, Loss: 0.0017
# Epoch 33/50, Loss: 0.0017
# Epoch 34/50, Loss: 0.0016
# Epoch 35/50, Loss: 0.0016
# Epoch 36/50, Loss: 0.0015
# Epoch 37/50, Loss: 0.0015
# Epoch 38/50, Loss: 0.0015
# Epoch 39/50, Loss: 0.0014
# Epoch 40/50, Loss: 0.0014
# Epoch 41/50, Loss: 0.0014
# Epoch 42/50, Loss: 0.0013
# Epoch 43/50, Loss: 0.0013
# Epoch 44/50, Loss: 0.0013
# Epoch 45/50, Loss: 0.0013
# Epoch 46/50, Loss: 0.0012
# Epoch 47/50, Loss: 0.0012
# Epoch 48/50, Loss: 0.0012
# Epoch 49/50, Loss: 0.0012
# Epoch 50/50, Loss: 0.0012
# Accuracy for subject S024: 38.46%
# Model for subject S024 saved to trained_model_S024.pth
#
# Results saved to /content/drive/My Drive/EEG_Data/Physionet/subject_accuracies.csv
#
# Training model for subject S023...
# Reading /content/drive/My Drive/EEG_Data/Physionet/S023/PA023-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Loaded data shape: (42, 64, 481)
# Epoch 1/50, Loss: 0.6869
# Epoch 2/50, Loss: 0.5055
# Epoch 3/50, Loss: 0.3921
# Epoch 4/50, Loss: 0.2952
# Epoch 5/50, Loss: 0.1947
# Epoch 6/50, Loss: 0.1395
# Epoch 7/50, Loss: 0.0846
# Epoch 8/50, Loss: 0.0423
# Epoch 9/50, Loss: 0.0233
# Epoch 10/50, Loss: 0.0147
# Epoch 11/50, Loss: 0.0100
# Epoch 12/50, Loss: 0.0071
# Epoch 13/50, Loss: 0.0054
# Epoch 14/50, Loss: 0.0043
# Epoch 15/50, Loss: 0.0036
# Epoch 16/50, Loss: 0.0031
# Epoch 17/50, Loss: 0.0028
# Epoch 18/50, Loss: 0.0025
# Epoch 19/50, Loss: 0.0023
# Epoch 20/50, Loss: 0.0022
# Epoch 21/50, Loss: 0.0020
# Epoch 22/50, Loss: 0.0019
# Epoch 23/50, Loss: 0.0018
# Epoch 24/50, Loss: 0.0017
# Epoch 25/50, Loss: 0.0017
# Epoch 26/50, Loss: 0.0016
# Epoch 27/50, Loss: 0.0015
# Epoch 28/50, Loss: 0.0015
# Epoch 29/50, Loss: 0.0014
# Epoch 30/50, Loss: 0.0014
# Epoch 31/50, Loss: 0.0014
# Epoch 32/50, Loss: 0.0013
# Epoch 33/50, Loss: 0.0013
# Epoch 34/50, Loss: 0.0013
# Epoch 35/50, Loss: 0.0013
# Epoch 36/50, Loss: 0.0012
# Epoch 37/50, Loss: 0.0012
# Epoch 38/50, Loss: 0.0012
# Epoch 39/50, Loss: 0.0012
# Epoch 40/50, Loss: 0.0011
# Epoch 41/50, Loss: 0.0011
# Epoch 42/50, Loss: 0.0011
# Epoch 43/50, Loss: 0.0011
# Epoch 44/50, Loss: 0.0011
# Epoch 45/50, Loss: 0.0011
# Epoch 46/50, Loss: 0.0010
# Epoch 47/50, Loss: 0.0010
# Epoch 48/50, Loss: 0.0010
# Epoch 49/50, Loss: 0.0010
# Epoch 50/50, Loss: 0.0010
# Accuracy for subject S023: 53.85%
# Model for subject S023 saved to trained_model_S023.pth
#
# Results saved to /content/drive/My Drive/EEG_Data/Physionet/subject_accuracies.csv
#
# Training model for subject S022...
# Reading /content/drive/My Drive/EEG_Data/Physionet/S022/PA022-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Loaded data shape: (42, 64, 481)
# Epoch 1/50, Loss: 0.7633
# Epoch 2/50, Loss: 0.6813
# Epoch 3/50, Loss: 0.5414
# Epoch 4/50, Loss: 0.4044
# Epoch 5/50, Loss: 0.3577
# Epoch 6/50, Loss: 0.3282
# Epoch 7/50, Loss: 0.2688
# Epoch 8/50, Loss: 0.2014
# Epoch 9/50, Loss: 0.1557
# Epoch 10/50, Loss: 0.1241
# Epoch 11/50, Loss: 0.0927
# Epoch 12/50, Loss: 0.0599
# Epoch 13/50, Loss: 0.0376
# Epoch 14/50, Loss: 0.0279
# Epoch 15/50, Loss: 0.0217
# Epoch 16/50, Loss: 0.0160
# Epoch 17/50, Loss: 0.0116
# Epoch 18/50, Loss: 0.0086
# Epoch 19/50, Loss: 0.0067
# Epoch 20/50, Loss: 0.0055
# Epoch 21/50, Loss: 0.0047
# Epoch 22/50, Loss: 0.0042
# Epoch 23/50, Loss: 0.0038
# Epoch 24/50, Loss: 0.0035
# Epoch 25/50, Loss: 0.0033
# Epoch 26/50, Loss: 0.0031
# Epoch 27/50, Loss: 0.0029
# Epoch 28/50, Loss: 0.0028
# Epoch 29/50, Loss: 0.0027
# Epoch 30/50, Loss: 0.0026
# Epoch 31/50, Loss: 0.0025
# Epoch 32/50, Loss: 0.0024
# Epoch 33/50, Loss: 0.0024
# Epoch 34/50, Loss: 0.0023
# Epoch 35/50, Loss: 0.0022
# Epoch 36/50, Loss: 0.0022
# Epoch 37/50, Loss: 0.0021
# Epoch 38/50, Loss: 0.0021
# Epoch 39/50, Loss: 0.0020
# Epoch 40/50, Loss: 0.0020
# Epoch 41/50, Loss: 0.0019
# Epoch 42/50, Loss: 0.0019
# Epoch 43/50, Loss: 0.0019
# Epoch 44/50, Loss: 0.0018
# Epoch 45/50, Loss: 0.0018
# Epoch 46/50, Loss: 0.0018
# Epoch 47/50, Loss: 0.0017
# Epoch 48/50, Loss: 0.0017
# Epoch 49/50, Loss: 0.0017
# Epoch 50/50, Loss: 0.0017
# Accuracy for subject S022: 46.15%
# Model for subject S022 saved to trained_model_S022.pth
#
# Results saved to /content/drive/My Drive/EEG_Data/Physionet/subject_accuracies.csv
#
# Training model for subject S021...
# Reading /content/drive/My Drive/EEG_Data/Physionet/S021/PA021-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Loaded data shape: (42, 64, 481)
# Epoch 1/50, Loss: 0.6636
# Epoch 2/50, Loss: 0.5086
# Epoch 3/50, Loss: 0.3758
# Epoch 4/50, Loss: 0.2662
# Epoch 5/50, Loss: 0.1551
# Epoch 6/50, Loss: 0.0912
# Epoch 7/50, Loss: 0.0449
# Epoch 8/50, Loss: 0.0215
# Epoch 9/50, Loss: 0.0124
# Epoch 10/50, Loss: 0.0085
# Epoch 11/50, Loss: 0.0064
# Epoch 12/50, Loss: 0.0052
# Epoch 13/50, Loss: 0.0044
# Epoch 14/50, Loss: 0.0039
# Epoch 15/50, Loss: 0.0035
# Epoch 16/50, Loss: 0.0032
# Epoch 17/50, Loss: 0.0030
# Epoch 18/50, Loss: 0.0028
# Epoch 19/50, Loss: 0.0027
# Epoch 20/50, Loss: 0.0026
# Epoch 21/50, Loss: 0.0025
# Epoch 22/50, Loss: 0.0024
# Epoch 23/50, Loss: 0.0023
# Epoch 24/50, Loss: 0.0022
# Epoch 25/50, Loss: 0.0021
# Epoch 26/50, Loss: 0.0021
# Epoch 27/50, Loss: 0.0020
# Epoch 28/50, Loss: 0.0020
# Epoch 29/50, Loss: 0.0019
# Epoch 30/50, Loss: 0.0019
# Epoch 31/50, Loss: 0.0018
# Epoch 32/50, Loss: 0.0018
# Epoch 33/50, Loss: 0.0018
# Epoch 34/50, Loss: 0.0017
# Epoch 35/50, Loss: 0.0017
# Epoch 36/50, Loss: 0.0017
# Epoch 37/50, Loss: 0.0016
# Epoch 38/50, Loss: 0.0016
# Epoch 39/50, Loss: 0.0016
# Epoch 40/50, Loss: 0.0015
# Epoch 41/50, Loss: 0.0015
# Epoch 42/50, Loss: 0.0015
# Epoch 43/50, Loss: 0.0015
# Epoch 44/50, Loss: 0.0015
# Epoch 45/50, Loss: 0.0014
# Epoch 46/50, Loss: 0.0014
# Epoch 47/50, Loss: 0.0014
# Epoch 48/50, Loss: 0.0014
# Epoch 49/50, Loss: 0.0014
# Epoch 50/50, Loss: 0.0013
# Accuracy for subject S021: 61.54%
# Model for subject S021 saved to trained_model_S021.pth
#
# Results saved to /content/drive/My Drive/EEG_Data/Physionet/subject_accuracies.csv
#
# Training model for subject S020...
# Reading /content/drive/My Drive/EEG_Data/Physionet/S020/PA020-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Loaded data shape: (42, 64, 481)
# Epoch 1/50, Loss: 0.7949
# Epoch 2/50, Loss: 0.8209
# Epoch 3/50, Loss: 0.5886
# Epoch 4/50, Loss: 0.4626
# Epoch 5/50, Loss: 0.4739
# Epoch 6/50, Loss: 0.4198
# Epoch 7/50, Loss: 0.3176
# Epoch 8/50, Loss: 0.2497
# Epoch 9/50, Loss: 0.2205
# Epoch 10/50, Loss: 0.1717
# Epoch 11/50, Loss: 0.1100
# Epoch 12/50, Loss: 0.0725
# Epoch 13/50, Loss: 0.0566
# Epoch 14/50, Loss: 0.0417
# Epoch 15/50, Loss: 0.0263
# Epoch 16/50, Loss: 0.0173
# Epoch 17/50, Loss: 0.0126
# Epoch 18/50, Loss: 0.0100
# Epoch 19/50, Loss: 0.0083
# Epoch 20/50, Loss: 0.0073
# Epoch 21/50, Loss: 0.0066
# Epoch 22/50, Loss: 0.0059
# Epoch 23/50, Loss: 0.0054
# Epoch 24/50, Loss: 0.0049
# Epoch 25/50, Loss: 0.0045
# Epoch 26/50, Loss: 0.0041
# Epoch 27/50, Loss: 0.0038
# Epoch 28/50, Loss: 0.0035
# Epoch 29/50, Loss: 0.0033
# Epoch 30/50, Loss: 0.0031
# Epoch 31/50, Loss: 0.0029
# Epoch 32/50, Loss: 0.0028
# Epoch 33/50, Loss: 0.0027
# Epoch 34/50, Loss: 0.0026
# Epoch 35/50, Loss: 0.0025
# Epoch 36/50, Loss: 0.0024
# Epoch 37/50, Loss: 0.0023
# Epoch 38/50, Loss: 0.0023
# Epoch 39/50, Loss: 0.0022
# Epoch 40/50, Loss: 0.0022
# Epoch 41/50, Loss: 0.0021
# Epoch 42/50, Loss: 0.0021
# Epoch 43/50, Loss: 0.0020
# Epoch 44/50, Loss: 0.0020
# Epoch 45/50, Loss: 0.0020
# Epoch 46/50, Loss: 0.0019
# Epoch 47/50, Loss: 0.0019
# Epoch 48/50, Loss: 0.0019
# Epoch 49/50, Loss: 0.0019
# Epoch 50/50, Loss: 0.0018
# Accuracy for subject S020: 53.85%
# Model for subject S020 saved to trained_model_S020.pth
#
# Results saved to /content/drive/My Drive/EEG_Data/Physionet/subject_accuracies.csv
#
# Training model for subject S019...
# Reading /content/drive/My Drive/EEG_Data/Physionet/S019/PA019-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Loaded data shape: (42, 64, 481)
# Epoch 1/50, Loss: 0.7001
# Epoch 2/50, Loss: 0.6364
# Epoch 3/50, Loss: 0.3607
# Epoch 4/50, Loss: 0.2962
# Epoch 5/50, Loss: 0.2272
# Epoch 6/50, Loss: 0.1255
# Epoch 7/50, Loss: 0.0637
# Epoch 8/50, Loss: 0.0369
# Epoch 9/50, Loss: 0.0231
# Epoch 10/50, Loss: 0.0148
# Epoch 11/50, Loss: 0.0103
# Epoch 12/50, Loss: 0.0077
# Epoch 13/50, Loss: 0.0061
# Epoch 14/50, Loss: 0.0050
# Epoch 15/50, Loss: 0.0043
# Epoch 16/50, Loss: 0.0038
# Epoch 17/50, Loss: 0.0034
# Epoch 18/50, Loss: 0.0031
# Epoch 19/50, Loss: 0.0029
# Epoch 20/50, Loss: 0.0027
# Epoch 21/50, Loss: 0.0025
# Epoch 22/50, Loss: 0.0024
# Epoch 23/50, Loss: 0.0023
# Epoch 24/50, Loss: 0.0022
# Epoch 25/50, Loss: 0.0021
# Epoch 26/50, Loss: 0.0020
# Epoch 27/50, Loss: 0.0020
# Epoch 28/50, Loss: 0.0019
# Epoch 29/50, Loss: 0.0018
# Epoch 30/50, Loss: 0.0018
# Epoch 31/50, Loss: 0.0017
# Epoch 32/50, Loss: 0.0017
# Epoch 33/50, Loss: 0.0017
# Epoch 34/50, Loss: 0.0016
# Epoch 35/50, Loss: 0.0016
# Epoch 36/50, Loss: 0.0016
# Epoch 37/50, Loss: 0.0015
# Epoch 38/50, Loss: 0.0015
# Epoch 39/50, Loss: 0.0015
# Epoch 40/50, Loss: 0.0014
# Epoch 41/50, Loss: 0.0014
# Epoch 42/50, Loss: 0.0014
# Epoch 43/50, Loss: 0.0014
# Epoch 44/50, Loss: 0.0014
# Epoch 45/50, Loss: 0.0013
# Epoch 46/50, Loss: 0.0013
# Epoch 47/50, Loss: 0.0013
# Epoch 48/50, Loss: 0.0013
# Epoch 49/50, Loss: 0.0013
# Epoch 50/50, Loss: 0.0013
# Accuracy for subject S019: 46.15%
# Model for subject S019 saved to trained_model_S019.pth
#
# Results saved to /content/drive/My Drive/EEG_Data/Physionet/subject_accuracies.csv
#
# Training model for subject S018...
# Reading /content/drive/My Drive/EEG_Data/Physionet/S018/PA018-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Loaded data shape: (42, 64, 481)
# Epoch 1/50, Loss: 0.6555
# Epoch 2/50, Loss: 0.7163
# Epoch 3/50, Loss: 0.4651
# Epoch 4/50, Loss: 0.5312
# Epoch 5/50, Loss: 0.4133
# Epoch 6/50, Loss: 0.3247
# Epoch 7/50, Loss: 0.3296
# Epoch 8/50, Loss: 0.2781
# Epoch 9/50, Loss: 0.1866
# Epoch 10/50, Loss: 0.1470
# Epoch 11/50, Loss: 0.1301
# Epoch 12/50, Loss: 0.0871
# Epoch 13/50, Loss: 0.0475
# Epoch 14/50, Loss: 0.0325
# Epoch 15/50, Loss: 0.0294
# Epoch 16/50, Loss: 0.0213
# Epoch 17/50, Loss: 0.0127
# Epoch 18/50, Loss: 0.0087
# Epoch 19/50, Loss: 0.0068
# Epoch 20/50, Loss: 0.0056
# Epoch 21/50, Loss: 0.0048
# Epoch 22/50, Loss: 0.0043
# Epoch 23/50, Loss: 0.0038
# Epoch 24/50, Loss: 0.0034
# Epoch 25/50, Loss: 0.0031
# Epoch 26/50, Loss: 0.0029
# Epoch 27/50, Loss: 0.0026
# Epoch 28/50, Loss: 0.0025
# Epoch 29/50, Loss: 0.0023
# Epoch 30/50, Loss: 0.0022
# Epoch 31/50, Loss: 0.0021
# Epoch 32/50, Loss: 0.0020
# Epoch 33/50, Loss: 0.0019
# Epoch 34/50, Loss: 0.0018
# Epoch 35/50, Loss: 0.0018
# Epoch 36/50, Loss: 0.0017
# Epoch 37/50, Loss: 0.0017
# Epoch 38/50, Loss: 0.0016
# Epoch 39/50, Loss: 0.0016
# Epoch 40/50, Loss: 0.0015
# Epoch 41/50, Loss: 0.0015
# Epoch 42/50, Loss: 0.0015
# Epoch 43/50, Loss: 0.0015
# Epoch 44/50, Loss: 0.0014
# Epoch 45/50, Loss: 0.0014
# Epoch 46/50, Loss: 0.0014
# Epoch 47/50, Loss: 0.0014
# Epoch 48/50, Loss: 0.0014
# Epoch 49/50, Loss: 0.0013
# Epoch 50/50, Loss: 0.0013
# Accuracy for subject S018: 53.85%
# Model for subject S018 saved to trained_model_S018.pth
#
# Results saved to /content/drive/My Drive/EEG_Data/Physionet/subject_accuracies.csv
#
# Training model for subject S017...
# Reading /content/drive/My Drive/EEG_Data/Physionet/S017/PA017-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Loaded data shape: (42, 64, 481)
# Epoch 1/50, Loss: 0.8767
# Epoch 2/50, Loss: 0.6825
# Epoch 3/50, Loss: 0.5500
# Epoch 4/50, Loss: 0.5214
# Epoch 5/50, Loss: 0.4605
# Epoch 6/50, Loss: 0.3948
# Epoch 7/50, Loss: 0.3519
# Epoch 8/50, Loss: 0.2978
# Epoch 9/50, Loss: 0.2292
# Epoch 10/50, Loss: 0.1775
# Epoch 11/50, Loss: 0.1355
# Epoch 12/50, Loss: 0.0872
# Epoch 13/50, Loss: 0.0561
# Epoch 14/50, Loss: 0.0420
# Epoch 15/50, Loss: 0.0276
# Epoch 16/50, Loss: 0.0166
# Epoch 17/50, Loss: 0.0111
# Epoch 18/50, Loss: 0.0082
# Epoch 19/50, Loss: 0.0066
# Epoch 20/50, Loss: 0.0056
# Epoch 21/50, Loss: 0.0049
# Epoch 22/50, Loss: 0.0043
# Epoch 23/50, Loss: 0.0039
# Epoch 24/50, Loss: 0.0036
# Epoch 25/50, Loss: 0.0033
# Epoch 26/50, Loss: 0.0031
# Epoch 27/50, Loss: 0.0029
# Epoch 28/50, Loss: 0.0027
# Epoch 29/50, Loss: 0.0026
# Epoch 30/50, Loss: 0.0025
# Epoch 31/50, Loss: 0.0024
# Epoch 32/50, Loss: 0.0023
# Epoch 33/50, Loss: 0.0022
# Epoch 34/50, Loss: 0.0021
# Epoch 35/50, Loss: 0.0020
# Epoch 36/50, Loss: 0.0020
# Epoch 37/50, Loss: 0.0019
# Epoch 38/50, Loss: 0.0019
# Epoch 39/50, Loss: 0.0018
# Epoch 40/50, Loss: 0.0018
# Epoch 41/50, Loss: 0.0017
# Epoch 42/50, Loss: 0.0017
# Epoch 43/50, Loss: 0.0017
# Epoch 44/50, Loss: 0.0016
# Epoch 45/50, Loss: 0.0016
# Epoch 46/50, Loss: 0.0016
# Epoch 47/50, Loss: 0.0016
# Epoch 48/50, Loss: 0.0015
# Epoch 49/50, Loss: 0.0015
# Epoch 50/50, Loss: 0.0015
# Accuracy for subject S017: 53.85%
# Model for subject S017 saved to trained_model_S017.pth
#
# Results saved to /content/drive/My Drive/EEG_Data/Physionet/subject_accuracies.csv
#
# Training model for subject S016...
# Reading /content/drive/My Drive/EEG_Data/Physionet/S016/PA016-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Loaded data shape: (42, 64, 481)
# Epoch 1/50, Loss: 0.7246
# Epoch 2/50, Loss: 0.5074
# Epoch 3/50, Loss: 0.3748
# Epoch 4/50, Loss: 0.2402
# Epoch 5/50, Loss: 0.1484
# Epoch 6/50, Loss: 0.0709
# Epoch 7/50, Loss: 0.0335
# Epoch 8/50, Loss: 0.0173
# Epoch 9/50, Loss: 0.0102
# Epoch 10/50, Loss: 0.0070
# Epoch 11/50, Loss: 0.0052
# Epoch 12/50, Loss: 0.0042
# Epoch 13/50, Loss: 0.0036
# Epoch 14/50, Loss: 0.0031
# Epoch 15/50, Loss: 0.0028
# Epoch 16/50, Loss: 0.0026
# Epoch 17/50, Loss: 0.0024
# Epoch 18/50, Loss: 0.0022
# Epoch 19/50, Loss: 0.0021
# Epoch 20/50, Loss: 0.0020
# Epoch 21/50, Loss: 0.0019
# Epoch 22/50, Loss: 0.0018
# Epoch 23/50, Loss: 0.0018
# Epoch 24/50, Loss: 0.0017
# Epoch 25/50, Loss: 0.0016
# Epoch 26/50, Loss: 0.0016
# Epoch 27/50, Loss: 0.0016
# Epoch 28/50, Loss: 0.0015
# Epoch 29/50, Loss: 0.0015
# Epoch 30/50, Loss: 0.0014
# Epoch 31/50, Loss: 0.0014
# Epoch 32/50, Loss: 0.0014
# Epoch 33/50, Loss: 0.0013
# Epoch 34/50, Loss: 0.0013
# Epoch 35/50, Loss: 0.0013
# Epoch 36/50, Loss: 0.0013
# Epoch 37/50, Loss: 0.0012
# Epoch 38/50, Loss: 0.0012
# Epoch 39/50, Loss: 0.0012
# Epoch 40/50, Loss: 0.0012
# Epoch 41/50, Loss: 0.0012
# Epoch 42/50, Loss: 0.0011
# Epoch 43/50, Loss: 0.0011
# Epoch 44/50, Loss: 0.0011
# Epoch 45/50, Loss: 0.0011
# Epoch 46/50, Loss: 0.0011
# Epoch 47/50, Loss: 0.0011
# Epoch 48/50, Loss: 0.0010
# Epoch 49/50, Loss: 0.0010
# Epoch 50/50, Loss: 0.0010
# Accuracy for subject S016: 46.15%
# Model for subject S016 saved to trained_model_S016.pth
#
# Results saved to /content/drive/My Drive/EEG_Data/Physionet/subject_accuracies.csv
#
# Training model for subject S015...
# Reading /content/drive/My Drive/EEG_Data/Physionet/S015/PA015-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Loaded data shape: (42, 64, 481)
# Epoch 1/50, Loss: 0.7050
# Epoch 2/50, Loss: 0.6736
# Epoch 3/50, Loss: 0.4189
# Epoch 4/50, Loss: 0.3989
# Epoch 5/50, Loss: 0.3012
# Epoch 6/50, Loss: 0.1691
# Epoch 7/50, Loss: 0.1047
# Epoch 8/50, Loss: 0.0726
# Epoch 9/50, Loss: 0.0428
# Epoch 10/50, Loss: 0.0228
# Epoch 11/50, Loss: 0.0129
# Epoch 12/50, Loss: 0.0083
# Epoch 13/50, Loss: 0.0059
# Epoch 14/50, Loss: 0.0046
# Epoch 15/50, Loss: 0.0037
# Epoch 16/50, Loss: 0.0032
# Epoch 17/50, Loss: 0.0028
# Epoch 18/50, Loss: 0.0024
# Epoch 19/50, Loss: 0.0022
# Epoch 20/50, Loss: 0.0020
# Epoch 21/50, Loss: 0.0019
# Epoch 22/50, Loss: 0.0018
# Epoch 23/50, Loss: 0.0017
# Epoch 24/50, Loss: 0.0016
# Epoch 25/50, Loss: 0.0015
# Epoch 26/50, Loss: 0.0014
# Epoch 27/50, Loss: 0.0014
# Epoch 28/50, Loss: 0.0013
# Epoch 29/50, Loss: 0.0013
# Epoch 30/50, Loss: 0.0012
# Epoch 31/50, Loss: 0.0012
# Epoch 32/50, Loss: 0.0012
# Epoch 33/50, Loss: 0.0011
# Epoch 34/50, Loss: 0.0011
# Epoch 35/50, Loss: 0.0011
# Epoch 36/50, Loss: 0.0011
# Epoch 37/50, Loss: 0.0010
# Epoch 38/50, Loss: 0.0010
# Epoch 39/50, Loss: 0.0010
# Epoch 40/50, Loss: 0.0010
# Epoch 41/50, Loss: 0.0010
# Epoch 42/50, Loss: 0.0010
# Epoch 43/50, Loss: 0.0009
# Epoch 44/50, Loss: 0.0009
# Epoch 45/50, Loss: 0.0009
# Epoch 46/50, Loss: 0.0009
# Epoch 47/50, Loss: 0.0009
# Epoch 48/50, Loss: 0.0009
# Epoch 49/50, Loss: 0.0009
# Epoch 50/50, Loss: 0.0009
# Accuracy for subject S015: 46.15%
# Model for subject S015 saved to trained_model_S015.pth
#
# Results saved to /content/drive/My Drive/EEG_Data/Physionet/subject_accuracies.csv
#
# Training model for subject S014...
# Reading /content/drive/My Drive/EEG_Data/Physionet/S014/PA014-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Loaded data shape: (42, 64, 481)
# Epoch 1/50, Loss: 0.7279
# Epoch 2/50, Loss: 0.7795
# Epoch 3/50, Loss: 0.5099
# Epoch 4/50, Loss: 0.3641
# Epoch 5/50, Loss: 0.3428
# Epoch 6/50, Loss: 0.2658
# Epoch 7/50, Loss: 0.1588
# Epoch 8/50, Loss: 0.0896
# Epoch 9/50, Loss: 0.0599
# Epoch 10/50, Loss: 0.0433
# Epoch 11/50, Loss: 0.0292
# Epoch 12/50, Loss: 0.0185
# Epoch 13/50, Loss: 0.0118
# Epoch 14/50, Loss: 0.0080
# Epoch 15/50, Loss: 0.0059
# Epoch 16/50, Loss: 0.0045
# Epoch 17/50, Loss: 0.0037
# Epoch 18/50, Loss: 0.0032
# Epoch 19/50, Loss: 0.0028
# Epoch 20/50, Loss: 0.0025
# Epoch 21/50, Loss: 0.0023
# Epoch 22/50, Loss: 0.0021
# Epoch 23/50, Loss: 0.0019
# Epoch 24/50, Loss: 0.0018
# Epoch 25/50, Loss: 0.0017
# Epoch 26/50, Loss: 0.0017
# Epoch 27/50, Loss: 0.0016
# Epoch 28/50, Loss: 0.0015
# Epoch 29/50, Loss: 0.0015
# Epoch 30/50, Loss: 0.0014
# Epoch 31/50, Loss: 0.0014
# Epoch 32/50, Loss: 0.0014
# Epoch 33/50, Loss: 0.0013
# Epoch 34/50, Loss: 0.0013
# Epoch 35/50, Loss: 0.0013
# Epoch 36/50, Loss: 0.0012
# Epoch 37/50, Loss: 0.0012
# Epoch 38/50, Loss: 0.0012
# Epoch 39/50, Loss: 0.0012
# Epoch 40/50, Loss: 0.0011
# Epoch 41/50, Loss: 0.0011
# Epoch 42/50, Loss: 0.0011
# Epoch 43/50, Loss: 0.0011
# Epoch 44/50, Loss: 0.0011
# Epoch 45/50, Loss: 0.0011
# Epoch 46/50, Loss: 0.0011
# Epoch 47/50, Loss: 0.0010
# Epoch 48/50, Loss: 0.0010
# Epoch 49/50, Loss: 0.0010
# Epoch 50/50, Loss: 0.0010
# Accuracy for subject S014: 23.08%
# Model for subject S014 saved to trained_model_S014.pth
#
# Results saved to /content/drive/My Drive/EEG_Data/Physionet/subject_accuracies.csv
#
# Training model for subject S013...
# Reading /content/drive/My Drive/EEG_Data/Physionet/S013/PA013-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Loaded data shape: (42, 64, 481)
# Epoch 1/50, Loss: 0.7559
# Epoch 2/50, Loss: 0.8413
# Epoch 3/50, Loss: 0.5339
# Epoch 4/50, Loss: 0.3949
# Epoch 5/50, Loss: 0.3959
# Epoch 6/50, Loss: 0.2999
# Epoch 7/50, Loss: 0.1811
# Epoch 8/50, Loss: 0.1184
# Epoch 9/50, Loss: 0.0903
# Epoch 10/50, Loss: 0.0646
# Epoch 11/50, Loss: 0.0385
# Epoch 12/50, Loss: 0.0214
# Epoch 13/50, Loss: 0.0129
# Epoch 14/50, Loss: 0.0085
# Epoch 15/50, Loss: 0.0063
# Epoch 16/50, Loss: 0.0050
# Epoch 17/50, Loss: 0.0041
# Epoch 18/50, Loss: 0.0035
# Epoch 19/50, Loss: 0.0031
# Epoch 20/50, Loss: 0.0028
# Epoch 21/50, Loss: 0.0025
# Epoch 22/50, Loss: 0.0024
# Epoch 23/50, Loss: 0.0022
# Epoch 24/50, Loss: 0.0021
# Epoch 25/50, Loss: 0.0020
# Epoch 26/50, Loss: 0.0019
# Epoch 27/50, Loss: 0.0018
# Epoch 28/50, Loss: 0.0017
# Epoch 29/50, Loss: 0.0017
# Epoch 30/50, Loss: 0.0016
# Epoch 31/50, Loss: 0.0016
# Epoch 32/50, Loss: 0.0015
# Epoch 33/50, Loss: 0.0015
# Epoch 34/50, Loss: 0.0014
# Epoch 35/50, Loss: 0.0014
# Epoch 36/50, Loss: 0.0014
# Epoch 37/50, Loss: 0.0014
# Epoch 38/50, Loss: 0.0013
# Epoch 39/50, Loss: 0.0013
# Epoch 40/50, Loss: 0.0013
# Epoch 41/50, Loss: 0.0013
# Epoch 42/50, Loss: 0.0012
# Epoch 43/50, Loss: 0.0012
# Epoch 44/50, Loss: 0.0012
# Epoch 45/50, Loss: 0.0012
# Epoch 46/50, Loss: 0.0012
# Epoch 47/50, Loss: 0.0012
# Epoch 48/50, Loss: 0.0011
# Epoch 49/50, Loss: 0.0011
# Epoch 50/50, Loss: 0.0011
# Accuracy for subject S013: 69.23%
# Model for subject S013 saved to trained_model_S013.pth
#
# Results saved to /content/drive/My Drive/EEG_Data/Physionet/subject_accuracies.csv
#
# Training model for subject S002...
# Reading /content/drive/My Drive/EEG_Data/Physionet/S002/PA002-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Loaded data shape: (42, 64, 481)
# Epoch 1/50, Loss: 0.7633
# Epoch 2/50, Loss: 0.8261
# Epoch 3/50, Loss: 0.5378
# Epoch 4/50, Loss: 0.4376
# Epoch 5/50, Loss: 0.4228
# Epoch 6/50, Loss: 0.3192
# Epoch 7/50, Loss: 0.1987
# Epoch 8/50, Loss: 0.1300
# Epoch 9/50, Loss: 0.0977
# Epoch 10/50, Loss: 0.0698
# Epoch 11/50, Loss: 0.0420
# Epoch 12/50, Loss: 0.0237
# Epoch 13/50, Loss: 0.0143
# Epoch 14/50, Loss: 0.0095
# Epoch 15/50, Loss: 0.0070
# Epoch 16/50, Loss: 0.0056
# Epoch 17/50, Loss: 0.0046
# Epoch 18/50, Loss: 0.0040
# Epoch 19/50, Loss: 0.0036
# Epoch 20/50, Loss: 0.0032
# Epoch 21/50, Loss: 0.0030
# Epoch 22/50, Loss: 0.0028
# Epoch 23/50, Loss: 0.0026
# Epoch 24/50, Loss: 0.0025
# Epoch 25/50, Loss: 0.0023
# Epoch 26/50, Loss: 0.0022
# Epoch 27/50, Loss: 0.0022
# Epoch 28/50, Loss: 0.0021
# Epoch 29/50, Loss: 0.0020
# Epoch 30/50, Loss: 0.0019
# Epoch 31/50, Loss: 0.0019
# Epoch 32/50, Loss: 0.0018
# Epoch 33/50, Loss: 0.0018
# Epoch 34/50, Loss: 0.0018
# Epoch 35/50, Loss: 0.0017
# Epoch 36/50, Loss: 0.0017
# Epoch 37/50, Loss: 0.0017
# Epoch 38/50, Loss: 0.0016
# Epoch 39/50, Loss: 0.0016
# Epoch 40/50, Loss: 0.0016
# Epoch 41/50, Loss: 0.0015
# Epoch 42/50, Loss: 0.0015
# Epoch 43/50, Loss: 0.0015
# Epoch 44/50, Loss: 0.0015
# Epoch 45/50, Loss: 0.0015
# Epoch 46/50, Loss: 0.0014
# Epoch 47/50, Loss: 0.0014
# Epoch 48/50, Loss: 0.0014
# Epoch 49/50, Loss: 0.0014
# Epoch 50/50, Loss: 0.0014
# Accuracy for subject S002: 69.23%
# Model for subject S002 saved to trained_model_S002.pth
#
# Results saved to /content/drive/My Drive/EEG_Data/Physionet/subject_accuracies.csv
#
# Training model for subject S001...
# Reading /content/drive/My Drive/EEG_Data/Physionet/S001/PA001-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Loaded data shape: (42, 64, 481)
# Epoch 1/50, Loss: 0.8336
# Epoch 2/50, Loss: 0.6405
# Epoch 3/50, Loss: 0.4840
# Epoch 4/50, Loss: 0.3369
# Epoch 5/50, Loss: 0.2766
# Epoch 6/50, Loss: 0.2495
# Epoch 7/50, Loss: 0.2087
# Epoch 8/50, Loss: 0.1489
# Epoch 9/50, Loss: 0.0897
# Epoch 10/50, Loss: 0.0517
# Epoch 11/50, Loss: 0.0339
# Epoch 12/50, Loss: 0.0254
# Epoch 13/50, Loss: 0.0201
# Epoch 14/50, Loss: 0.0153
# Epoch 15/50, Loss: 0.0112
# Epoch 16/50, Loss: 0.0078
# Epoch 17/50, Loss: 0.0058
# Epoch 18/50, Loss: 0.0045
# Epoch 19/50, Loss: 0.0037
# Epoch 20/50, Loss: 0.0032
# Epoch 21/50, Loss: 0.0028
# Epoch 22/50, Loss: 0.0025
# Epoch 23/50, Loss: 0.0023
# Epoch 24/50, Loss: 0.0022
# Epoch 25/50, Loss: 0.0020
# Epoch 26/50, Loss: 0.0019
# Epoch 27/50, Loss: 0.0018
# Epoch 28/50, Loss: 0.0018
# Epoch 29/50, Loss: 0.0017
# Epoch 30/50, Loss: 0.0016
# Epoch 31/50, Loss: 0.0016
# Epoch 32/50, Loss: 0.0015
# Epoch 33/50, Loss: 0.0015
# Epoch 34/50, Loss: 0.0015
# Epoch 35/50, Loss: 0.0014
# Epoch 36/50, Loss: 0.0014
# Epoch 37/50, Loss: 0.0014
# Epoch 38/50, Loss: 0.0013
# Epoch 39/50, Loss: 0.0013
# Epoch 40/50, Loss: 0.0013
# Epoch 41/50, Loss: 0.0013
# Epoch 42/50, Loss: 0.0012
# Epoch 43/50, Loss: 0.0012
# Epoch 44/50, Loss: 0.0012
# Epoch 45/50, Loss: 0.0012
# Epoch 46/50, Loss: 0.0012
# Epoch 47/50, Loss: 0.0011
# Epoch 48/50, Loss: 0.0011
# Epoch 49/50, Loss: 0.0011
# Epoch 50/50, Loss: 0.0011
# Accuracy for subject S001: 53.85%
# Model for subject S001 saved to trained_model_S001.pth
#
# Results saved to /content/drive/My Drive/EEG_Data/Physionet/subject_accuracies.csv
#
# Training model for subject S049...
# Reading /content/drive/My Drive/EEG_Data/Physionet/S049/PA049-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Loaded data shape: (42, 64, 481)
# Epoch 1/50, Loss: 0.7108
# Epoch 2/50, Loss: 0.5613
# Epoch 3/50, Loss: 0.3769
# Epoch 4/50, Loss: 0.2930
# Epoch 5/50, Loss: 0.1643
# Epoch 6/50, Loss: 0.0940
# Epoch 7/50, Loss: 0.0558
# Epoch 8/50, Loss: 0.0282
# Epoch 9/50, Loss: 0.0137
# Epoch 10/50, Loss: 0.0079
# Epoch 11/50, Loss: 0.0053
# Epoch 12/50, Loss: 0.0040
# Epoch 13/50, Loss: 0.0032
# Epoch 14/50, Loss: 0.0027
# Epoch 15/50, Loss: 0.0023
# Epoch 16/50, Loss: 0.0021
# Epoch 17/50, Loss: 0.0019
# Epoch 18/50, Loss: 0.0017
# Epoch 19/50, Loss: 0.0016
# Epoch 20/50, Loss: 0.0015
# Epoch 21/50, Loss: 0.0014
# Epoch 22/50, Loss: 0.0014
# Epoch 23/50, Loss: 0.0013
# Epoch 24/50, Loss: 0.0012
# Epoch 25/50, Loss: 0.0012
# Epoch 26/50, Loss: 0.0011
# Epoch 27/50, Loss: 0.0011
# Epoch 28/50, Loss: 0.0011
# Epoch 29/50, Loss: 0.0010
# Epoch 30/50, Loss: 0.0010
# Epoch 31/50, Loss: 0.0010
# Epoch 32/50, Loss: 0.0010
# Epoch 33/50, Loss: 0.0009
# Epoch 34/50, Loss: 0.0009
# Epoch 35/50, Loss: 0.0009
# Epoch 36/50, Loss: 0.0009
# Epoch 37/50, Loss: 0.0009
# Epoch 38/50, Loss: 0.0008
# Epoch 39/50, Loss: 0.0008
# Epoch 40/50, Loss: 0.0008
# Epoch 41/50, Loss: 0.0008
# Epoch 42/50, Loss: 0.0008
# Epoch 43/50, Loss: 0.0008
# Epoch 44/50, Loss: 0.0008
# Epoch 45/50, Loss: 0.0008
# Epoch 46/50, Loss: 0.0008
# Epoch 47/50, Loss: 0.0007
# Epoch 48/50, Loss: 0.0007
# Epoch 49/50, Loss: 0.0007
# Epoch 50/50, Loss: 0.0007
# Accuracy for subject S049: 46.15%
# Model for subject S049 saved to trained_model_S049.pth
#
# Results saved to /content/drive/My Drive/EEG_Data/Physionet/subject_accuracies.csv
#
# Training model for subject S043...
# Reading /content/drive/My Drive/EEG_Data/Physionet/S043/PA043-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Loaded data shape: (42, 64, 481)
# Epoch 1/50, Loss: 0.7736
# Epoch 2/50, Loss: 0.7487
# Epoch 3/50, Loss: 0.5687
# Epoch 4/50, Loss: 0.5850
# Epoch 5/50, Loss: 0.5087
# Epoch 6/50, Loss: 0.4253
# Epoch 7/50, Loss: 0.3926
# Epoch 8/50, Loss: 0.3539
# Epoch 9/50, Loss: 0.2894
# Epoch 10/50, Loss: 0.2360
# Epoch 11/50, Loss: 0.2027
# Epoch 12/50, Loss: 0.1631
# Epoch 13/50, Loss: 0.1137
# Epoch 14/50, Loss: 0.0782
# Epoch 15/50, Loss: 0.0597
# Epoch 16/50, Loss: 0.0427
# Epoch 17/50, Loss: 0.0260
# Epoch 18/50, Loss: 0.0145
# Epoch 19/50, Loss: 0.0090
# Epoch 20/50, Loss: 0.0063
# Epoch 21/50, Loss: 0.0047
# Epoch 22/50, Loss: 0.0036
# Epoch 23/50, Loss: 0.0029
# Epoch 24/50, Loss: 0.0024
# Epoch 25/50, Loss: 0.0020
# Epoch 26/50, Loss: 0.0018
# Epoch 27/50, Loss: 0.0016
# Epoch 28/50, Loss: 0.0014
# Epoch 29/50, Loss: 0.0013
# Epoch 30/50, Loss: 0.0012
# Epoch 31/50, Loss: 0.0011
# Epoch 32/50, Loss: 0.0011
# Epoch 33/50, Loss: 0.0010
# Epoch 34/50, Loss: 0.0010
# Epoch 35/50, Loss: 0.0009
# Epoch 36/50, Loss: 0.0009
# Epoch 37/50, Loss: 0.0009
# Epoch 38/50, Loss: 0.0008
# Epoch 39/50, Loss: 0.0008
# Epoch 40/50, Loss: 0.0008
# Epoch 41/50, Loss: 0.0008
# Epoch 42/50, Loss: 0.0007
# Epoch 43/50, Loss: 0.0007
# Epoch 44/50, Loss: 0.0007
# Epoch 45/50, Loss: 0.0007
# Epoch 46/50, Loss: 0.0007
# Epoch 47/50, Loss: 0.0007
# Epoch 48/50, Loss: 0.0007
# Epoch 49/50, Loss: 0.0007
# ...
# Epoch 13/50, Loss: 0.0080
# Epoch 14/50, Loss: 0.0059
# Epoch 15/50, Loss: 0.0046
# Epoch 16/50, Loss: 0.0038
# Epoch 17/50, Loss: 0.0033
# Epoch 18/50, Loss: 0.0029
# Epoch 19/50, Loss: 0.0026
# Epoch 20/50, Loss: 0.0024
# Epoch 21/50, Loss: 0.0022
# Epoch 22/50, Loss: 0.0021
# Epoch 23/50, Loss: 0.0020
# Epoch 24/50, Loss: 0.0019
# Epoch 25/50, Loss: 0.0018
# Epoch 26/50, Loss: 0.0017
# Epoch 27/50, Loss: 0.0017
# Epoch 28/50, Loss: 0.0016
# Epoch 29/50, Loss: 0.0016
# Epoch 30/50, Loss: 0.0015
# Epoch 31/50, Loss: 0.0015
# Epoch 32/50, Loss: 0.0014
# Epoch 33/50, Loss: 0.0014
# Epoch 34/50, Loss: 0.0014
# Epoch 35/50, Loss: 0.0014
# Epoch 36/50, Loss: 0.0013
# Epoch 37/50, Loss: 0.0013
# Epoch 38/50, Loss: 0.0013
# Epoch 39/50, Loss: 0.0013
# Epoch 40/50, Loss: 0.0012
# Epoch 41/50, Loss: 0.0012
# Epoch 42/50, Loss: 0.0012
# Epoch 43/50, Loss: 0.0012
# Epoch 44/50, Loss: 0.0012
# Epoch 45/50, Loss: 0.0012
# Epoch 46/50, Loss: 0.0011
# Epoch 47/50, Loss: 0.0011
# Epoch 48/50, Loss: 0.0011
# Epoch 49/50, Loss: 0.0011
# Epoch 50/50, Loss: 0.0011
# Accuracy for subject S003: 46.15%
# Model for subject S003 saved to trained_model_S003.pth
#
# Results saved to /content/drive/My Drive/EEG_Data/Physionet/subject_accuracies.csv
#
# Training model for subject S050...
# Reading /content/drive/My Drive/EEG_Data/Physionet/S050/PA050-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Loaded data shape: (42, 64, 481)
# Epoch 1/50, Loss: 0.6956
# Epoch 2/50, Loss: 0.6094
# Epoch 3/50, Loss: 0.3014
# Epoch 4/50, Loss: 0.2784
# Epoch 5/50, Loss: 0.1851
# Epoch 6/50, Loss: 0.0830
# Epoch 7/50, Loss: 0.0434
# Epoch 8/50, Loss: 0.0325
# Epoch 9/50, Loss: 0.0239
# Epoch 10/50, Loss: 0.0152
# Epoch 11/50, Loss: 0.0090
# Epoch 12/50, Loss: 0.0056
# Epoch 13/50, Loss: 0.0038
# Epoch 14/50, Loss: 0.0028
# Epoch 15/50, Loss: 0.0022
# Epoch 16/50, Loss: 0.0018
# Epoch 17/50, Loss: 0.0016
# Epoch 18/50, Loss: 0.0014
# Epoch 19/50, Loss: 0.0013
# Epoch 20/50, Loss: 0.0012
# Epoch 21/50, Loss: 0.0011
# Epoch 22/50, Loss: 0.0010
# Epoch 23/50, Loss: 0.0010
# Epoch 24/50, Loss: 0.0009
# Epoch 25/50, Loss: 0.0009
# Epoch 26/50, Loss: 0.0008
# Epoch 27/50, Loss: 0.0008
# Epoch 28/50, Loss: 0.0008
# Epoch 29/50, Loss: 0.0008
# Epoch 30/50, Loss: 0.0008
# Epoch 31/50, Loss: 0.0007
# Epoch 32/50, Loss: 0.0007
# Epoch 33/50, Loss: 0.0007
# Epoch 34/50, Loss: 0.0007
# Epoch 35/50, Loss: 0.0007
# Epoch 36/50, Loss: 0.0007
# Epoch 37/50, Loss: 0.0007
# Epoch 38/50, Loss: 0.0006
# Epoch 39/50, Loss: 0.0006
# Epoch 40/50, Loss: 0.0006
# Epoch 41/50, Loss: 0.0006
# Epoch 42/50, Loss: 0.0006
# Epoch 43/50, Loss: 0.0006
# Epoch 44/50, Loss: 0.0006
# Epoch 45/50, Loss: 0.0006
# Epoch 46/50, Loss: 0.0006
# Epoch 47/50, Loss: 0.0006
# Epoch 48/50, Loss: 0.0006
# Epoch 49/50, Loss: 0.0006
# Epoch 50/50, Loss: 0.0006
# Accuracy for subject S050: 84.62%
# Model for subject S050 saved to trained_model_S050.pth
#
# Results saved to /content/drive/My Drive/EEG_Data/Physionet/subject_accuracies.csv
#
# Training model for subject S052...
# Reading /content/drive/My Drive/EEG_Data/Physionet/S052/PA052-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Loaded data shape: (42, 64, 481)
# Epoch 1/50, Loss: 0.7220
# Epoch 2/50, Loss: 0.8207
# Epoch 3/50, Loss: 0.5606
# Epoch 4/50, Loss: 0.4661
# Epoch 5/50, Loss: 0.4951
# Epoch 6/50, Loss: 0.4084
# Epoch 7/50, Loss: 0.3069
# Epoch 8/50, Loss: 0.2685
# Epoch 9/50, Loss: 0.2483
# Epoch 10/50, Loss: 0.1983
# Epoch 11/50, Loss: 0.1336
# Epoch 12/50, Loss: 0.0956
# Epoch 13/50, Loss: 0.0817
# Epoch 14/50, Loss: 0.0629
# Epoch 15/50, Loss: 0.0379
# Epoch 16/50, Loss: 0.0217
# Epoch 17/50, Loss: 0.0149
# Epoch 18/50, Loss: 0.0116
# Epoch 19/50, Loss: 0.0098
# Epoch 20/50, Loss: 0.0085
# Epoch 21/50, Loss: 0.0072
# Epoch 22/50, Loss: 0.0062
# Epoch 23/50, Loss: 0.0053
# Epoch 24/50, Loss: 0.0045
# Epoch 25/50, Loss: 0.0040
# Epoch 26/50, Loss: 0.0035
# Epoch 27/50, Loss: 0.0030
# Epoch 28/50, Loss: 0.0028
# Epoch 29/50, Loss: 0.0025
# Epoch 30/50, Loss: 0.0023
# Epoch 31/50, Loss: 0.0022
# Epoch 32/50, Loss: 0.0020
# Epoch 33/50, Loss: 0.0019
# Epoch 34/50, Loss: 0.0018
# Epoch 35/50, Loss: 0.0018
# Epoch 36/50, Loss: 0.0017
# Epoch 37/50, Loss: 0.0016
# Epoch 38/50, Loss: 0.0016
# Epoch 39/50, Loss: 0.0015
# Epoch 40/50, Loss: 0.0015
# Epoch 41/50, Loss: 0.0014
# Epoch 42/50, Loss: 0.0014
# Epoch 43/50, Loss: 0.0014
# Epoch 44/50, Loss: 0.0013
# Epoch 45/50, Loss: 0.0013
# Epoch 46/50, Loss: 0.0013
# Epoch 47/50, Loss: 0.0013
# Epoch 48/50, Loss: 0.0013
# Epoch 49/50, Loss: 0.0012
# Epoch 50/50, Loss: 0.0012
# Accuracy for subject S052: 38.46%
# Model for subject S052 saved to trained_model_S052.pth
#
# Results saved to /content/drive/My Drive/EEG_Data/Physionet/subject_accuracies.csv
#
# Training model for subject S009...
# Reading /content/drive/My Drive/EEG_Data/Physionet/S009/PA009-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Loaded data shape: (42, 64, 481)
# Epoch 1/50, Loss: 0.7439
# Epoch 2/50, Loss: 0.7427
# Epoch 3/50, Loss: 0.5428
# Epoch 4/50, Loss: 0.4964
# Epoch 5/50, Loss: 0.4614
# Epoch 6/50, Loss: 0.3585
# Epoch 7/50, Loss: 0.2629
# Epoch 8/50, Loss: 0.2064
# Epoch 9/50, Loss: 0.1520
# Epoch 10/50, Loss: 0.0913
# Epoch 11/50, Loss: 0.0514
# Epoch 12/50, Loss: 0.0314
# Epoch 13/50, Loss: 0.0210
# Epoch 14/50, Loss: 0.0150
# Epoch 15/50, Loss: 0.0115
# Epoch 16/50, Loss: 0.0093
# Epoch 17/50, Loss: 0.0076
# Epoch 18/50, Loss: 0.0064
# Epoch 19/50, Loss: 0.0055
# Epoch 20/50, Loss: 0.0047
# Epoch 21/50, Loss: 0.0041
# Epoch 22/50, Loss: 0.0037
# Epoch 23/50, Loss: 0.0034
# Epoch 24/50, Loss: 0.0031
# Epoch 25/50, Loss: 0.0029
# Epoch 26/50, Loss: 0.0027
# Epoch 27/50, Loss: 0.0026
# Epoch 28/50, Loss: 0.0025
# Epoch 29/50, Loss: 0.0024
# Epoch 30/50, Loss: 0.0023
# Epoch 31/50, Loss: 0.0022
# Epoch 32/50, Loss: 0.0022
# Epoch 33/50, Loss: 0.0021
# Epoch 34/50, Loss: 0.0020
# Epoch 35/50, Loss: 0.0020
# Epoch 36/50, Loss: 0.0019
# Epoch 37/50, Loss: 0.0019
# Epoch 38/50, Loss: 0.0019
# Epoch 39/50, Loss: 0.0018
# Epoch 40/50, Loss: 0.0018
# Epoch 41/50, Loss: 0.0018
# Epoch 42/50, Loss: 0.0017
# Epoch 43/50, Loss: 0.0017
# Epoch 44/50, Loss: 0.0017
# Epoch 45/50, Loss: 0.0017
# Epoch 46/50, Loss: 0.0016
# Epoch 47/50, Loss: 0.0016
# Epoch 48/50, Loss: 0.0016
# Epoch 49/50, Loss: 0.0016
# Epoch 50/50, Loss: 0.0015
# Accuracy for subject S009: 69.23%
# Model for subject S009 saved to trained_model_S009.pth
#
# Results saved to /content/drive/My Drive/EEG_Data/Physionet/subject_accuracies.csv
#
# Training model for subject S012...
# Reading /content/drive/My Drive/EEG_Data/Physionet/S012/PA012-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Loaded data shape: (42, 64, 481)
# Epoch 1/50, Loss: 0.7334
# Epoch 2/50, Loss: 0.5503
# Epoch 3/50, Loss: 0.4109
# Epoch 4/50, Loss: 0.3493
# Epoch 5/50, Loss: 0.2624
# Epoch 6/50, Loss: 0.1833
# Epoch 7/50, Loss: 0.1258
# Epoch 8/50, Loss: 0.0720
# Epoch 9/50, Loss: 0.0424
# Epoch 10/50, Loss: 0.0272
# Epoch 11/50, Loss: 0.0169
# Epoch 12/50, Loss: 0.0109
# Epoch 13/50, Loss: 0.0079
# Epoch 14/50, Loss: 0.0061
# Epoch 15/50, Loss: 0.0051
# Epoch 16/50, Loss: 0.0043
# Epoch 17/50, Loss: 0.0038
# Epoch 18/50, Loss: 0.0035
# Epoch 19/50, Loss: 0.0032
# Epoch 20/50, Loss: 0.0030
# Epoch 21/50, Loss: 0.0028
# Epoch 22/50, Loss: 0.0027
# Epoch 23/50, Loss: 0.0025
# Epoch 24/50, Loss: 0.0024
# Epoch 25/50, Loss: 0.0023
# Epoch 26/50, Loss: 0.0022
# Epoch 27/50, Loss: 0.0022
# Epoch 28/50, Loss: 0.0021
# Epoch 29/50, Loss: 0.0020
# Epoch 30/50, Loss: 0.0020
# Epoch 31/50, Loss: 0.0019
# Epoch 32/50, Loss: 0.0019
# Epoch 33/50, Loss: 0.0018
# Epoch 34/50, Loss: 0.0018
# Epoch 35/50, Loss: 0.0017
# Epoch 36/50, Loss: 0.0017
# Epoch 37/50, Loss: 0.0017
# Epoch 38/50, Loss: 0.0016
# Epoch 39/50, Loss: 0.0016
# Epoch 40/50, Loss: 0.0016
# Epoch 41/50, Loss: 0.0016
# Epoch 42/50, Loss: 0.0015
# Epoch 43/50, Loss: 0.0015
# Epoch 44/50, Loss: 0.0015
# Epoch 45/50, Loss: 0.0015
# Epoch 46/50, Loss: 0.0014
# Epoch 47/50, Loss: 0.0014
# Epoch 48/50, Loss: 0.0014
# Epoch 49/50, Loss: 0.0014
# Epoch 50/50, Loss: 0.0014
# Accuracy for subject S012: 69.23%
# Model for subject S012 saved to trained_model_S012.pth
#
# Results saved to /content/drive/My Drive/EEG_Data/Physionet/subject_accuracies.csv
#
# Training model for subject S011...
# Reading /content/drive/My Drive/EEG_Data/Physionet/S011/PA011-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Loaded data shape: (42, 64, 481)
# Epoch 1/50, Loss: 0.7075
# Epoch 2/50, Loss: 0.6282
# Epoch 3/50, Loss: 0.4642
# Epoch 4/50, Loss: 0.4188
# Epoch 5/50, Loss: 0.3170
# Epoch 6/50, Loss: 0.2245
# Epoch 7/50, Loss: 0.1685
# Epoch 8/50, Loss: 0.1090
# Epoch 9/50, Loss: 0.0584
# Epoch 10/50, Loss: 0.0336
# Epoch 11/50, Loss: 0.0217
# Epoch 12/50, Loss: 0.0155
# Epoch 13/50, Loss: 0.0116
# Epoch 14/50, Loss: 0.0090
# Epoch 15/50, Loss: 0.0072
# Epoch 16/50, Loss: 0.0060
# Epoch 17/50, Loss: 0.0051
# Epoch 18/50, Loss: 0.0044
# Epoch 19/50, Loss: 0.0039
# Epoch 20/50, Loss: 0.0036
# Epoch 21/50, Loss: 0.0033
# Epoch 22/50, Loss: 0.0031
# Epoch 23/50, Loss: 0.0029
# Epoch 24/50, Loss: 0.0027
# Epoch 25/50, Loss: 0.0026
# Epoch 26/50, Loss: 0.0025
# Epoch 27/50, Loss: 0.0024
# Epoch 28/50, Loss: 0.0023
# Epoch 29/50, Loss: 0.0022
# Epoch 30/50, Loss: 0.0021
# Epoch 31/50, Loss: 0.0021
# Epoch 32/50, Loss: 0.0020
# Epoch 33/50, Loss: 0.0019
# Epoch 34/50, Loss: 0.0019
# Epoch 35/50, Loss: 0.0019
# Epoch 36/50, Loss: 0.0018
# Epoch 37/50, Loss: 0.0018
# Epoch 38/50, Loss: 0.0017
# Epoch 39/50, Loss: 0.0017
# Epoch 40/50, Loss: 0.0017
# Epoch 41/50, Loss: 0.0017
# Epoch 42/50, Loss: 0.0016
# Epoch 43/50, Loss: 0.0016
# Epoch 44/50, Loss: 0.0016
# Epoch 45/50, Loss: 0.0015
# Epoch 46/50, Loss: 0.0015
# Epoch 47/50, Loss: 0.0015
# Epoch 48/50, Loss: 0.0015
# Epoch 49/50, Loss: 0.0015
# Epoch 50/50, Loss: 0.0014
# Accuracy for subject S011: 84.62%
# Model for subject S011 saved to trained_model_S011.pth
#
# Results saved to /content/drive/My Drive/EEG_Data/Physionet/subject_accuracies.csv
#
# Training model for subject S010...
# Reading /content/drive/My Drive/EEG_Data/Physionet/S010/PA010-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Loaded data shape: (42, 64, 481)
# Epoch 1/50, Loss: 0.7797
# Epoch 2/50, Loss: 0.7250
# Epoch 3/50, Loss: 0.6217
# Epoch 4/50, Loss: 0.4974
# Epoch 5/50, Loss: 0.4577
# Epoch 6/50, Loss: 0.4240
# Epoch 7/50, Loss: 0.3658
# Epoch 8/50, Loss: 0.3162
# Epoch 9/50, Loss: 0.2784
# Epoch 10/50, Loss: 0.2429
# Epoch 11/50, Loss: 0.2205
# Epoch 12/50, Loss: 0.1916
# Epoch 13/50, Loss: 0.1612
# Epoch 14/50, Loss: 0.1559
# Epoch 15/50, Loss: 0.1414
# Epoch 16/50, Loss: 0.1186
# Epoch 17/50, Loss: 0.1053
# Epoch 18/50, Loss: 0.0795
# Epoch 19/50, Loss: 0.0554
# Epoch 20/50, Loss: 0.0487
# Epoch 21/50, Loss: 0.0435
# Epoch 22/50, Loss: 0.0331
# Epoch 23/50, Loss: 0.0273
# Epoch 24/50, Loss: 0.0176
# Epoch 25/50, Loss: 0.0116
# Epoch 26/50, Loss: 0.0097
# Epoch 27/50, Loss: 0.0081
# Epoch 28/50, Loss: 0.0058
# Epoch 29/50, Loss: 0.0042
# Epoch 30/50, Loss: 0.0032
# Epoch 31/50, Loss: 0.0027
# Epoch 32/50, Loss: 0.0023
# Epoch 33/50, Loss: 0.0020
# Epoch 34/50, Loss: 0.0019
# Epoch 35/50, Loss: 0.0018
# Epoch 36/50, Loss: 0.0016
# Epoch 37/50, Loss: 0.0016
# Epoch 38/50, Loss: 0.0015
# Epoch 39/50, Loss: 0.0014
# Epoch 40/50, Loss: 0.0014
# Epoch 41/50, Loss: 0.0013
# Epoch 42/50, Loss: 0.0013
# Epoch 43/50, Loss: 0.0013
# Epoch 44/50, Loss: 0.0012
# Epoch 45/50, Loss: 0.0012
# Epoch 46/50, Loss: 0.0012
# Epoch 47/50, Loss: 0.0012
# Epoch 48/50, Loss: 0.0012
# Epoch 49/50, Loss: 0.0011
# Epoch 50/50, Loss: 0.0011
# Accuracy for subject S010: 76.92%
# Model for subject S010 saved to trained_model_S010.pth
#
# Results saved to /content/drive/My Drive/EEG_Data/Physionet/subject_accuracies.csv
#
# Training model for subject S036...
# Reading /content/drive/My Drive/EEG_Data/Physionet/S036/PA036-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Loaded data shape: (42, 64, 481)
# Epoch 1/50, Loss: 0.6622
# Epoch 2/50, Loss: 0.6434
# Epoch 3/50, Loss: 0.3890
# Epoch 4/50, Loss: 0.3414
# Epoch 5/50, Loss: 0.2677
# Epoch 6/50, Loss: 0.1547
# Epoch 7/50, Loss: 0.0848
# Epoch 8/50, Loss: 0.0553
# Epoch 9/50, Loss: 0.0371
# Epoch 10/50, Loss: 0.0230
# Epoch 11/50, Loss: 0.0144
# Epoch 12/50, Loss: 0.0098
# Epoch 13/50, Loss: 0.0073
# Epoch 14/50, Loss: 0.0057
# Epoch 15/50, Loss: 0.0047
# Epoch 16/50, Loss: 0.0041
# Epoch 17/50, Loss: 0.0036
# Epoch 18/50, Loss: 0.0033
# Epoch 19/50, Loss: 0.0030
# Epoch 20/50, Loss: 0.0028
# Epoch 21/50, Loss: 0.0026
# Epoch 22/50, Loss: 0.0025
# Epoch 23/50, Loss: 0.0024
# Epoch 24/50, Loss: 0.0023
# Epoch 25/50, Loss: 0.0022
# Epoch 26/50, Loss: 0.0021
# Epoch 27/50, Loss: 0.0021
# Epoch 28/50, Loss: 0.0020
# Epoch 29/50, Loss: 0.0019
# Epoch 30/50, Loss: 0.0019
# Epoch 31/50, Loss: 0.0019
# Epoch 32/50, Loss: 0.0018
# Epoch 33/50, Loss: 0.0018
# Epoch 34/50, Loss: 0.0017
# Epoch 35/50, Loss: 0.0017
# Epoch 36/50, Loss: 0.0017
# Epoch 37/50, Loss: 0.0017
# Epoch 38/50, Loss: 0.0016
# Epoch 39/50, Loss: 0.0016
# Epoch 40/50, Loss: 0.0016
# Epoch 41/50, Loss: 0.0016
# Epoch 42/50, Loss: 0.0015
# Epoch 43/50, Loss: 0.0015
# Epoch 44/50, Loss: 0.0015
# Epoch 45/50, Loss: 0.0015
# Epoch 46/50, Loss: 0.0015
# Epoch 47/50, Loss: 0.0014
# Epoch 48/50, Loss: 0.0014
# Epoch 49/50, Loss: 0.0014
# Epoch 50/50, Loss: 0.0014
# Accuracy for subject S036: 46.15%
# Model for subject S036 saved to trained_model_S036.pth
#
# Results saved to /content/drive/My Drive/EEG_Data/Physionet/subject_accuracies.csv
#
# Training model for subject S035...
# Reading /content/drive/My Drive/EEG_Data/Physionet/S035/PA035-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Loaded data shape: (42, 64, 481)
# Epoch 1/50, Loss: 0.7306
# Epoch 2/50, Loss: 0.8031
# Epoch 3/50, Loss: 0.7095
# Epoch 4/50, Loss: 0.6340
# Epoch 5/50, Loss: 0.6198
# Epoch 6/50, Loss: 0.6318
# Epoch 7/50, Loss: 0.6027
# Epoch 8/50, Loss: 0.5466
# Epoch 9/50, Loss: 0.5079
# Epoch 10/50, Loss: 0.4773
# Epoch 11/50, Loss: 0.4185
# Epoch 12/50, Loss: 0.3496
# Epoch 13/50, Loss: 0.2795
# Epoch 14/50, Loss: 0.2126
# Epoch 15/50, Loss: 0.1818
# Epoch 16/50, Loss: 0.1337
# Epoch 17/50, Loss: 0.0833
# Epoch 18/50, Loss: 0.0617
# Epoch 19/50, Loss: 0.0432
# Epoch 20/50, Loss: 0.0271
# Epoch 21/50, Loss: 0.0204
# Epoch 22/50, Loss: 0.0166
# Epoch 23/50, Loss: 0.0120
# Epoch 24/50, Loss: 0.0098
# Epoch 25/50, Loss: 0.0085
# Epoch 26/50, Loss: 0.0072
# Epoch 27/50, Loss: 0.0061
# Epoch 28/50, Loss: 0.0054
# Epoch 29/50, Loss: 0.0049
# Epoch 30/50, Loss: 0.0045
# Epoch 31/50, Loss: 0.0043
# Epoch 32/50, Loss: 0.0041
# Epoch 33/50, Loss: 0.0040
# Epoch 34/50, Loss: 0.0038
# Epoch 35/50, Loss: 0.0037
# Epoch 36/50, Loss: 0.0036
# Epoch 37/50, Loss: 0.0034
# Epoch 38/50, Loss: 0.0033
# Epoch 39/50, Loss: 0.0032
# Epoch 40/50, Loss: 0.0031
# Epoch 41/50, Loss: 0.0030
# Epoch 42/50, Loss: 0.0029
# Epoch 43/50, Loss: 0.0028
# Epoch 44/50, Loss: 0.0028
# Epoch 45/50, Loss: 0.0027
# Epoch 46/50, Loss: 0.0026
# Epoch 47/50, Loss: 0.0026
# Epoch 48/50, Loss: 0.0026
# Epoch 49/50, Loss: 0.0025
# Epoch 50/50, Loss: 0.0025
# Accuracy for subject S035: 53.85%
# Model for subject S035 saved to trained_model_S035.pth
#
# Results saved to /content/drive/My Drive/EEG_Data/Physionet/subject_accuracies.csv

# %% [markdown]
# ---
#
# # <font color="pink">Cross-individual</font>

# %%
def train_cross_individual(model_class, learning_rate):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    results = []
    total_correct = 0
    total_samples = 0

    all_subjects = sorted(os.listdir(preprocessed_data_dir))
    subject_data = {}

    # Load all data once
    for subj_folder in all_subjects:
        subj_folder_path = os.path.join(preprocessed_data_dir, subj_folder)
        file_path = os.path.join(subj_folder_path, f"PA{subj_folder[1:]}-3s-epo.fif")
        if os.path.exists(file_path):
            X, y = load_subject_data(file_path)
            subject_data[subj_folder] = (X, y)

    for test_subj in subject_data:
        print(f"\nTesting on subject {test_subj}...")

        X_test, y_test = subject_data[test_subj]

        X_train_all = []
        y_train_all = []

        for train_subj, (X, y) in subject_data.items():
            if train_subj != test_subj:
                X_train_all.append(X)
                y_train_all.append(y)

        X_train = np.concatenate(X_train_all, axis=0)
        y_train = np.concatenate(y_train_all, axis=0)

        cnn_mode = model_class.__name__ in cnn_models
        train_dataset = EEGDataset(X_train, y_train, cnn_mode)
        test_dataset = EEGDataset(X_test, y_test, cnn_mode)

        train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
        test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

        if "Spatial" in model_class.__name__:
            input_size = X_train.shape[2]
        elif "Temporal" in model_class.__name__:
            input_size = X_train.shape[1]
        else:
            input_size = X_train.shape[2]

        model = model_class(input_size=input_size, d_model=d_model, nhead=nhead, num_classes=num_classes)
        train_model(model, train_loader=train_loader, test_loader=test_loader, device=device, lr=learning_rate)

        accuracy = evaluate_model(model, test_loader, device)
        print(f"Accuracy on subject {test_subj}: {accuracy * 100:.2f}%")
        results.append([test_subj, accuracy * 100])

        total_samples += len(test_dataset)
        total_correct += accuracy * len(test_dataset)

        # Save model
        model_save_path = f"cross_model_{test_subj}.pth"
        torch.save(model.state_dict(), model_save_path)

    overall_accuracy = total_correct / total_samples
    print(f"\nOverall cross-subject accuracy: {overall_accuracy * 100:.2f}%")

    # Save results to CSV
    output_csv = f"/content/drive/My Drive/EEG_Data/Physionet/cross_subject_accuracies_{model_class.__name__ }.csv"
    with open(output_csv, mode='w', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(["Subject", "Accuracy"])
        writer.writerows(results)
        writer.writerow(["Overall", overall_accuracy * 100])
    print(f"Results saved to {output_csv}")

# %% [markdown]
# ---
#
# # <font color="pink">5fold cross-individual</font>

# %%
from sklearn.model_selection import KFold


def train_5fold_cross_validation(model_class, learning_rate):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    results = []
    total_correct = 0
    total_samples = 0
    input_size = 0

    all_subjects = sorted(os.listdir(preprocessed_data_dir))
    subject_data = {}

    # Load all data once
    for subj_folder in all_subjects:
        subj_folder_path = os.path.join(preprocessed_data_dir, subj_folder)
        file_path = os.path.join(subj_folder_path, f"PA{subj_folder[1:]}-3s-epo.fif")
        if os.path.exists(file_path):
            X, y = load_subject_data(file_path)
            subject_data[subj_folder] = (X, y)

    # Split the subjects into 5 folds using KFold
    kf = KFold(n_splits=5, shuffle=True, random_state=42)

    for fold, (train_idx, test_idx) in enumerate(kf.split(subject_data)):
        print(f"\nFold {fold + 1}/5")

        # Create the training and test datasets for this fold
        X_train_all = []
        y_train_all = []
        X_test_all = []
        y_test_all = []

        # Prepare the train and test data based on the current fold
        for idx in train_idx:
            subj_folder = list(subject_data.keys())[idx]
            X, y = subject_data[subj_folder]
            X_train_all.append(X)
            y_train_all.append(y)

        for idx in test_idx:
            subj_folder = list(subject_data.keys())[idx]
            X, y = subject_data[subj_folder]
            X_test_all.append(X)
            y_test_all.append(y)

        # Convert lists into numpy arrays
        X_train = np.concatenate(X_train_all, axis=0)
        y_train = np.concatenate(y_train_all, axis=0)
        X_test = np.concatenate(X_test_all, axis=0)
        y_test = np.concatenate(y_test_all, axis=0)

        # Create DataLoader for train and test datasets
        cnn_mode = model_class.__name__ in cnn_models
        print("cnn_mode:", cnn_mode)
        train_dataset = EEGDataset(X_train, y_train, cnn_mode)
        test_dataset = EEGDataset(X_test, y_test, cnn_mode)

        train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
        test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

        if "Spatial" in model_class.__name__:
            input_size = X_train.shape[2]
        elif "Temporal" in model_class.__name__:
            input_size = X_train.shape[1]
        else:
            input_size = X_train.shape[2]

        model = model_class(input_size=input_size, d_model=d_model, nhead=nhead, num_classes=num_classes)
        train_model(model, train_loader=train_loader, test_loader=test_loader, device=device, lr=learning_rate)

        # Evaluate model on the test data
        accuracy = evaluate_model(model, test_loader, device)
        print(f"Accuracy for fold {fold + 1}: {accuracy * 100:.2f}%")
        results.append(accuracy)

        total_samples += len(test_dataset)
        total_correct += accuracy * len(test_dataset)

    # Calculate the average accuracy across all folds
    average_accuracy = np.mean(results)
    print(f"\nAverage accuracy across 5 folds: {average_accuracy * 100:.2f}%")

    # Save results to CSV
    output_csv = f"/content/drive/My Drive/EEG_Data/Physionet/fold_cross_subject_accuracies_{model_class.__name__ }.csv"
    with open(output_csv, mode='w', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(["Fold", "Accuracy"])
        for i, acc in enumerate(results):
            writer.writerow([f"Fold {i + 1}", acc * 100])
        writer.writerow(["Average", average_accuracy * 100])
    print(f"Results saved to {output_csv}")

# %%
#train_cross_individual(SpatialTransformer, learning_rate=7e-4)
# train_5fold_cross_validation(SpatialTransformer, learning_rate=7e-4)
# train_5fold_cross_validation(TemporalCNNTransformer, learning_rate=7e-4)
train_5fold_cross_validation(SpatialTransformer, learning_rate=7e-4)
# Out:
# Reading /content/drive/My Drive/EEG_Data/Physionet/S001/PA001-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S002/PA002-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S003/PA003-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S004/PA004-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S005/PA005-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S006/PA006-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S007/PA007-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S008/PA008-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S009/PA009-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S010/PA010-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S011/PA011-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S012/PA012-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S013/PA013-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S014/PA014-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S015/PA015-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S016/PA016-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S017/PA017-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S018/PA018-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S019/PA019-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S020/PA020-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S021/PA021-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S022/PA022-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S023/PA023-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S024/PA024-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S025/PA025-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S026/PA026-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S027/PA027-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S028/PA028-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S029/PA029-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S030/PA030-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S031/PA031-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S032/PA032-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S033/PA033-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S034/PA034-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S035/PA035-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S036/PA036-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S037/PA037-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S038/PA038-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S039/PA039-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S040/PA040-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S041/PA041-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S042/PA042-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S043/PA043-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S044/PA044-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S045/PA045-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S046/PA046-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S047/PA047-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S048/PA048-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S049/PA049-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S050/PA050-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S051/PA051-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /content/drive/My Drive/EEG_Data/Physionet/S052/PA052-3s-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =    2000.00 ...    5000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 42 matching events found
# No baseline correction applied
# 0 projection items activated
#
# Fold 1/5
# cnn_mode: False
# Epoch 1/50, Loss: 37.8115
# Epoch 2/50, Loss: 36.4068
# Epoch 3/50, Loss: 34.6729
# Epoch 4/50, Loss: 33.1617
# Epoch 5/50, Loss: 30.5638
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-66fb72fba8df> in <cell line: 0>()
#       2 # train_5fold_cross_validation(SpatialTransformer, learning_rate=7e-4)
#       3 # train_5fold_cross_validation(TemporalCNNTransformer, learning_rate=7e-4)
# ----> 4 train_5fold_cross_validation(SpatialTransformer, learning_rate=7e-4)
#
# <ipython-input-21-1782aa9df696> in train_5fold_cross_validation(model_class, learning_rate)
#      68
#      69         model = model_class(input_size=input_size, d_model=d_model, nhead=nhead, num_classes=num_classes)
# ---> 70         train_model(model, train_loader=train_loader, test_loader=test_loader, device=device, lr=learning_rate)
#      71
#      72         # Evaluate model on the test data
#
# <ipython-input-13-c43faf2a9245> in train_model(model, train_loader, test_loader, device, lr)
#      52       X_batch, y_batch = X_batch.to(device), y_batch.to(device)
#      53       optimizer.zero_grad()
# ---> 54       output = model(X_batch)
#      55       loss = criterion(output, y_batch)
#      56       loss.backward()
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# <ipython-input-6-7b17c0a5b0b1> in forward(self, x)
#      16     x = self.embedding(x)
#      17     x = self.pos_encoder(x)
# ---> 18     x = self.transformer(x)
#      19     x = x.mean(dim=0)
#      20     return self.fc(x)
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     248     def forward(self, input):
#     249         for module in self:
# --> 250             input = module(input)
#     251         return input
#     252
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# <ipython-input-4-e6fc1d56b61f> in forward(self, x)
#      40     It helps the gradient flow backward during training.
#      41     """
# ---> 42     x = self.norm1(x + attn_output)
#      43     ff_output = self.ff(x)
#      44     x = self.norm2(x + ff_output)
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/normalization.py in forward(self, input)
#     215
#     216     def forward(self, input: Tensor) -> Tensor:
# --> 217         return F.layer_norm(
#     218             input, self.normalized_shape, self.weight, self.bias, self.eps
#     219         )
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/functional.py in layer_norm(input, normalized_shape, weight, bias, eps)
#    2908             eps=eps,
#    2909         )
# -> 2910     return torch.layer_norm(
#    2911         input, normalized_shape, weight, bias, eps, torch.backends.cudnn.enabled
#    2912     )
#
# KeyboardInterrupt:
